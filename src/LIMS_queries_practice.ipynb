# %% [markdown]
# # We want to access data in LIMS, but how?

# %%
import pg8000          #pg8000 access SQL databases
import pandas as pd    #pandas will be needed to work in a dataframe
import csv
import os
import pathlib2
import warnings
import numpy as np
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Helpful functions for accessing LIMS

# %%
#code from Agata
#these are nice functions to open LIMS, make a query and then close LIMS after

def _connect(user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    conn = pg8000.connect(user=user, host=host, database=database, password=password, port=port)
    return conn, conn.cursor()

def _select(cursor, query):
    cursor.execute(query)
    columns = [ d[0] for d in cursor.description ]
    return [ dict(zip(columns, c)) for c in cursor.fetchall() ]

def limsquery(query, user="limsreader", host="limsdb2", database="lims2", password="limsro", port=5432):
    """A function that takes a string containing a SQL query, connects to the LIMS database and outputs the result."""
    conn, cursor = _connect(user, host, database, password, port)
    try:
        results = _select(cursor, query)
    finally:
        
        #THESE ARE IMPORTANT!!!!!!
        #Every query needs to be closed when done
        cursor.close()             
        conn.close()
    return results


#this last function will take our query results and put them in a dataframe so that they are easy to work with
def get_lims_dataframe(query):
    '''Return a dataframe with lims query'''
    result = limsquery(query)
    try:
        data_df = pd.DataFrame(data=result, columns=result[0].keys())
    except IndexError:
        print "Could not find results for your query."
        data_df = pd.DataFrame()
    return data_df

# %% [markdown]
# ### What are the elements named in LIMS?

# %% [markdown]
# #### This is an easy way to search through the tables in LIMS to find out what columns are called

# %%
my_query = "SELECT * FROM donors LIMIT 1"
#we are going to select all columns in the specimens table and limit our search to the first 10

my_result = limsquery(my_query)

first_element = my_result
#now we only want to look at the first element of our result

print sorted(first_element)
#print my_result
# Out:
# ['age_id', 'baseline_weight_g', 'created_at', 'created_by', 'data', 'date_of_birth', 'death_cause_id', 'death_manner_id', 'death_on', 'education_level_id', 'external_donor_name', 'full_genotype', 'gender_id', 'handedness_id', 'height', 'id', 'induction_method', 'name', 'occupation_id', 'organism_id', 'primary_tissue_source_id', 'race_id', 'transgenic_induction_method_id', 'updated_at', 'updated_by', 'weight']

# %%
my_query = "SELECT * FROM specimens LIMIT 1"
#we are going to select all columns in the specimens table and limit our search to the first 10

my_result = limsquery(my_query)

first_element = my_result[0]
#now we only want to look at the first element of our result

print sorted(first_element)
# Out:
# ['alignment3d_id', 'barcode', 'biophysical_model_state', 'carousel_well_name', 'cell_depth', 'cell_label', 'cell_prep_id', 'cell_reporter_id', 'cortex_layer_id', 'created_at', 'created_by', 'data', 'donor_id', 'ephys_cell_plan_id', 'ephys_neural_tissue_plan_id', 'ephys_qc_result', 'ephys_roi_result_id', 'ephys_start_time_sec', 'external_specimen_name', 'facs_well_id', 'flipped_specimen_id', 'frozen_at', 'hemisphere_id', 'histology_well_name', 'id', 'location_id', 'name', 'normalization_group_id', 'operation_id', 'parent_id', 'parent_x_coord', 'parent_y_coord', 'parent_z_coord', 'patched_cell_container', 'pinned_radius', 'plane_of_section_id', 'postmortem_interval_id', 'preparation_method_id', 'priority', 'project_id', 'reference_space_id', 'rna_integrity_number', 'specimen_preparation_method_id', 'specimen_set_id', 'storage_directory', 'structure_id', 'task_flow_id', 'tissue_ph', 'tissue_processing_id', 'updated_at', 'updated_by', 'x_coord', 'y_coord']

# %% [markdown]
# ### There is a lot to process there, but it looks like a dictionary. Let's search another table, but this time only look at the keys so we know what info LIMS is giving us

# %%
my_query = "SELECT * FROM ephys_roi_results LIMIT 1"
my_result = limsquery(my_query)
#my_result = get_lims_dataframe(my_query)
first_element = my_result[0]
print first_element.keys()
#print my_result
#lims_df = get_lims_dataframe(my_query)
#lims_df.head()
# Out:
# ['rig_name', 'ephys_qc_criteria_id', 'failed_bad_rs', 'updated_at', 'storage_directory', 'electrode_0_pa', 'input_resistance_mohm', 'id', 'stage2_reviewer_id', 'blowout_mv', 'failed_other', 'sampling_rate', 'input_access_resistance_ratio', 'failed_no_seal', 'workflow_state', 'ephys_specimen_roi_plan_id', 'initial_access_resistance_mohm', 'qc_notes', 'recording_date', 'created_at', 'seal_gohm', 'published_at', 'failed_clogged_pipette', 'stage1_reviewer_id', 'failed_electrode_0', 'notes']

# %% [markdown]
# ## What other tables are out there?

# %%
my_query = "SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES"
my_result = limsquery(my_query)
my_result
# Out:
# [{'table_name': u'pg_type'},
#  {'table_name': u'pg_roles'},
#  {'table_name': u'pg_group'},
#  {'table_name': u'pg_user'},
#  {'table_name': u'pg_rules'},
#  {'table_name': u'pg_views'},
#  {'table_name': u'pg_tables'},
#  {'table_name': u'pg_matviews'},
#  {'table_name': u'pg_indexes'},
#  {'table_name': u'pg_stats'},
#  {'table_name': u'pg_settings'},
#  {'table_name': u'pg_locks'},
#  {'table_name': u'pg_cursors'},
#  {'table_name': u'pg_available_extensions'},
#  {'table_name': u'pg_available_extension_versions'},
#  {'table_name': u'pg_prepared_xacts'},
#  {'table_name': u'pg_prepared_statements'},
#  {'table_name': u'pg_seclabels'},
#  {'table_name': u'pg_timezone_abbrevs'},
#  {'table_name': u'pg_timezone_names'},
#  {'table_name': u'pg_stat_all_tables'},
#  {'table_name': u'pg_stat_xact_all_tables'},
#  {'table_name': u'pg_stat_sys_tables'},
#  {'table_name': u'pg_stat_xact_sys_tables'},
#  {'table_name': u'pg_stat_user_tables'},
#  {'table_name': u'pg_stat_xact_user_tables'},
#  {'table_name': u'pg_statio_all_tables'},
#  {'table_name': u'pg_statio_sys_tables'},
#  {'table_name': u'pg_statio_user_tables'},
#  {'table_name': u'pg_statio_all_indexes'},
#  {'table_name': u'pg_statio_sys_indexes'},
#  {'table_name': u'pg_statio_user_indexes'},
#  {'table_name': u'pg_statio_all_sequences'},
#  {'table_name': u'pg_statio_sys_sequences'},
#  {'table_name': u'pg_statio_user_sequences'},
#  {'table_name': u'pg_stat_activity'},
#  {'table_name': u'pg_stat_replication'},
#  {'table_name': u'pg_replication_slots'},
#  {'table_name': u'pg_stat_database'},
#  {'table_name': u'pg_stat_database_conflicts'},
#  {'table_name': u'pg_stat_user_functions'},
#  {'table_name': u'pg_stat_xact_user_functions'},
#  {'table_name': u'pg_stat_archiver'},
#  {'table_name': u'pg_stat_bgwriter'},
#  {'table_name': u'pg_user_mappings'},
#  {'table_name': u'pg_stat_all_indexes'},
#  {'table_name': u'pg_stat_sys_indexes'},
#  {'table_name': u'pg_stat_user_indexes'},
#  {'table_name': u'information_schema_catalog_name'},
#  {'table_name': u'applicable_roles'},
#  {'table_name': u'administrable_role_authorizations'},
#  {'table_name': u'attributes'},
#  {'table_name': u'character_sets'},
#  {'table_name': u'check_constraint_routine_usage'},
#  {'table_name': u'check_constraints'},
#  {'table_name': u'collations'},
#  {'table_name': u'collation_character_set_applicability'},
#  {'table_name': u'column_domain_usage'},
#  {'table_name': u'column_privileges'},
#  {'table_name': u'column_udt_usage'},
#  {'table_name': u'columns'},
#  {'table_name': u'constraint_column_usage'},
#  {'table_name': u'constraint_table_usage'},
#  {'table_name': u'domain_constraints'},
#  {'table_name': u'domain_udt_usage'},
#  {'table_name': u'domains'},
#  {'table_name': u'enabled_roles'},
#  {'table_name': u'key_column_usage'},
#  {'table_name': u'parameters'},
#  {'table_name': u'referential_constraints'},
#  {'table_name': u'role_column_grants'},
#  {'table_name': u'routine_privileges'},
#  {'table_name': u'role_routine_grants'},
#  {'table_name': u'routines'},
#  {'table_name': u'schemata'},
#  {'table_name': u'sequences'},
#  {'table_name': u'pg_attribute'},
#  {'table_name': u'pg_proc'},
#  {'table_name': u'table_constraints'},
#  {'table_name': u'table_privileges'},
#  {'table_name': u'role_table_grants'},
#  {'table_name': u'tables'},
#  {'table_name': u'triggered_update_columns'},
#  {'table_name': u'triggers'},
#  {'table_name': u'udt_privileges'},
#  {'table_name': u'role_udt_grants'},
#  {'table_name': u'usage_privileges'},
#  {'table_name': u'role_usage_grants'},
#  {'table_name': u'user_defined_types'},
#  {'table_name': u'view_column_usage'},
#  {'table_name': u'view_routine_usage'},
#  {'table_name': u'view_table_usage'},
#  {'table_name': u'views'},
#  {'table_name': u'data_type_privileges'},
#  {'table_name': u'element_types'},
#  {'table_name': u'column_options'},
#  {'table_name': u'foreign_data_wrapper_options'},
#  {'table_name': u'foreign_data_wrappers'},
#  {'table_name': u'foreign_server_options'},
#  {'table_name': u'foreign_servers'},
#  {'table_name': u'foreign_table_options'},
#  {'table_name': u'foreign_tables'},
#  {'table_name': u'user_mapping_options'},
#  {'table_name': u'user_mappings'},
#  {'table_name': u'pg_constraint'},
#  {'table_name': u'pg_index'},
#  {'table_name': u'pg_operator'},
#  {'table_name': u'pg_opfamily'},
#  {'table_name': u'pg_opclass'},
#  {'table_name': u'pg_am'},
#  {'table_name': u'executables'},
#  {'table_name': u'rseq_experiment_components_star_analysis_runs'},
#  {'table_name': u'rgb_values'},
#  {'table_name': u'rseq_tube_inputs'},
#  {'table_name': u'ephys_qc_criterias'},
#  {'table_name': u'rseq_tubes'},
#  {'table_name': u'transcripts'},
#  {'table_name': u'cell_prep_samples_specimens'},
#  {'table_name': u'methods_versions_task_templates'},
#  {'table_name': u'ophys_experiment_analysis_runs'},
#  {'table_name': u'refseq_human_gff_37'},
#  {'table_name': u'rseq_experiments'},
#  {'table_name': u'pg_depend'},
#  {'table_name': u'analysis_run_containers'},
#  {'table_name': u'image_structure_data'},
#  {'table_name': u'avg_graphic_objects'},
#  {'table_name': u'avg_microarray_templates'},
#  {'table_name': u'wij_sets'},
#  {'table_name': u'avg_transformations'},
#  {'table_name': u'loci'},
#  {'table_name': u'sessions'},
#  {'table_name': u'task_templates'},
#  {'table_name': u'job_queue_notification_field_values'},
#  {'table_name': u'flipped_specimens'},
#  {'table_name': u'job_queue_notifications_users'},
#  {'table_name': u'rseq_library_preps'},
#  {'table_name': u'sub_images'},
#  {'table_name': u'sql_languages'},
#  {'table_name': u'sql_packages'},
#  {'table_name': u'sql_sizing'},
#  {'table_name': u'sql_sizing_profiles'},
#  {'table_name': u'genomic_reference_updates'},
#  {'table_name': u'graph_views'},
#  {'table_name': u'differentiation_designs_differentiation_stages'},
#  {'table_name': u'handednesses'},
#  {'table_name': u'ephys_roi_results'},
#  {'table_name': u'primers'},
#  {'table_name': u'differentiation_designs'},
#  {'table_name': u'annovaluemaps'},
#  {'table_name': u'refseq_macaque_gff'},
#  {'table_name': u'well_known_file_types'},
#  {'table_name': u'wij_chunks'},
#  {'table_name': u'annotationdetail'},
#  {'table_name': u'differentiation_stage_instances'},
#  {'table_name': u'orphanedannotationsets'},
#  {'table_name': u'probe_expressed_states'},
#  {'table_name': u'postupdate'},
#  {'table_name': u'orphanedentities'},
#  {'table_name': u'equipment_runplans'},
#  {'table_name': u'donors_genotypes'},
#  {'table_name': u'email_aliases'},
#  {'table_name': u'genotype_types'},
#  {'table_name': u'probe_alignments'},
#  {'table_name': u'planregionmaps'},
#  {'table_name': u'planregionmapcells'},
#  {'table_name': u'linkannotation'},
#  {'table_name': u'cell_rois_roi_exclusion_labels'},
#  {'table_name': u'annotated_regions'},
#  {'table_name': u'api_column_definitions'},
#  {'table_name': u'cell_roi_analysis_runs'},
#  {'table_name': u'cell_rois_roi_exclusion_training_labels'},
#  {'table_name': u'ercc_sets'},
#  {'table_name': u'flat_field_correction_runs'},
#  {'table_name': u'organisms'},
#  {'table_name': u'project_sets'},
#  {'table_name': u'project_sets_projects'},
#  {'table_name': u'refseq_mouse_gff'},
#  {'table_name': u'roi_exclusion_labels'},
#  {'table_name': u'reference3d_spaces'},
#  {'table_name': u'reference_to_reference_transforms'},
#  {'table_name': u'roi_exclusion_training_labels'},
#  {'table_name': u'analysis_runs_types'},
#  {'table_name': u'ext_genes_v'},
#  {'table_name': u'cell_prep_samples'},
#  {'table_name': u'experiment_sessions'},
#  {'table_name': u'tissue_processings'},
#  {'table_name': u'ext_genes_image_series_v'},
#  {'table_name': u'ext_image_series_treatments_v'},
#  {'table_name': u'refseq_human_gff'},
#  {'table_name': u'rseq_experiment_components'},
#  {'table_name': u'scheduled_procedures_subjects'},
#  {'table_name': u'southern_blots'},
#  {'table_name': u'specimen_hierarchies'},
#  {'table_name': u'spatial_mappings'},
#  {'table_name': u'specimen_blocks'},
#  {'table_name': u'analysis_runs'},
#  {'table_name': u'cell_prep_roi_plans_cell_prep_templates'},
#  {'table_name': u'graph_views_structures'},
#  {'table_name': u'cdna_primer_report_views'},
#  {'table_name': u'injection_materials_surgical_procedures'},
#  {'table_name': u'hemispheres'},
#  {'table_name': u'cel1_nucleases'},
#  {'table_name': u'polygon_spatial_mappings'},
#  {'table_name': u'job_queue_notifications'},
#  {'table_name': u'specimen_metadata'},
#  {'table_name': u'job_queue_notification_criterias_job_queue_notifications'},
#  {'table_name': u'cell_additives'},
#  {'table_name': u'methods_versions_watchers'},
#  {'table_name': u'tasks_task_templates'},
#  {'table_name': u'surgical_procedures'},
#  {'table_name': u'affymetrix_probesets'},
#  {'table_name': u'behavior_protocols'},
#  {'table_name': u'job_queue_notifications_job_queues'},
#  {'table_name': u'job_queue_notification_reports_job_queue_notifications'},
#  {'table_name': u'job_queue_notification_field_values_job_queue_notifications'},
#  {'table_name': u'cultured_cells'},
#  {'table_name': u'ncbi_sequence_statuses'},
#  {'table_name': u'methods_versions'},
#  {'table_name': u'operation_locations_operations'},
#  {'table_name': u'colors'},
#  {'table_name': u'log_messages'},
#  {'table_name': u'methods_versions_ncrs'},
#  {'table_name': u'culture_conditions'},
#  {'table_name': u'macaque_chrs_map'},
#  {'table_name': u'neuron_reconstruction_tags'},
#  {'table_name': u'probe_pcr_products'},
#  {'table_name': u'probe_refseq_blast_results'},
#  {'table_name': u'color_channel_descriptions'},
#  {'table_name': u'cell_preps_cell_prep_roi_plans'},
#  {'table_name': u'mouse_chrs_map'},
#  {'table_name': u'operations'},
#  {'table_name': u'reference_spaces'},
#  {'table_name': u'clone_primer_report_views'},
#  {'table_name': u'cell_preps'},
#  {'table_name': u'behavior_time_blocks'},
#  {'table_name': u'ophys_cell_segmentation_runs'},
#  {'table_name': u'ephys_roi_plans'},
#  {'table_name': u'engineering_drug_instances'},
#  {'table_name': u'facs_population_plans_facs'},
#  {'table_name': u'behavior_trainings'},
#  {'table_name': u'donor_dna_construct_types'},
#  {'table_name': u'visual_behavior_details'},
#  {'table_name': u'ephys_neural_tissue_plans'},
#  {'table_name': u'donor_dna_connections'},
#  {'table_name': u'injection_material_propagation_directions'},
#  {'table_name': u'donor_dna_constructs_engineering_steps'},
#  {'table_name': u'differentiation_stages_task_flows'},
#  {'table_name': u'facs'},
#  {'table_name': u'donor_dna_construct_designs_donor_dna_promoters'},
#  {'table_name': u'biocytin_wells'},
#  {'table_name': u'differentiation_stages'},
#  {'table_name': u'cell_rois'},
#  {'table_name': u'specimen_tags'},
#  {'table_name': u'annotated_region_histories'},
#  {'table_name': u'runplan_states'},
#  {'table_name': u'ephys_neural_tissue_plans_ephys_roi_plans'},
#  {'table_name': u'specimens_workflows'},
#  {'table_name': u'ephys_sweep_tags_ephys_sweeps'},
#  {'table_name': u'cross_ontology_mappings'},
#  {'table_name': u'email_aliases_methods_version_types'},
#  {'table_name': u'ephys_raw_stimulus_names'},
#  {'table_name': u'specimen_types_specimens'},
#  {'table_name': u'animal_monitoring_details'},
#  {'table_name': u'specimen_sets_treatments'},
#  {'table_name': u'stem_cell_line_states'},
#  {'table_name': u'ephys_stimuli'},
#  {'table_name': u'ncrs_specimens'},
#  {'table_name': u'bam_anonymization_runs'},
#  {'table_name': u'executables_workflows'},
#  {'table_name': u'blocks'},
#  {'table_name': u'calculatedilutions_v'},
#  {'table_name': u'postmortem_intervals'},
#  {'table_name': u'ercc_stock_pool_components'},
#  {'table_name': u'scheduled_procedure_notifications_users'},
#  {'table_name': u'ephys_sweeps'},
#  {'table_name': u'primary_tissue_sources'},
#  {'table_name': u'executables_run_types'},
#  {'table_name': u'ext_genelookups_v'},
#  {'table_name': u'blast_db_types'},
#  {'table_name': u'avg_group_labels'},
#  {'table_name': u'cell_prep_sample_collection_types'},
#  {'table_name': u'executables_run_group_types'},
#  {'table_name': u'blast_db_files'},
#  {'table_name': u'cell_prep_sample_types'},
#  {'table_name': u'blast_versions'},
#  {'table_name': u'differentiation_sets'},
#  {'table_name': u'email_aliases_projects'},
#  {'table_name': u'ext_structures_v'},
#  {'table_name': u'facs_sops'},
#  {'table_name': u'flat_structures_v'},
#  {'table_name': u'operation_types'},
#  {'table_name': u'scheduled_procedure_notification_date_ranges_scheduled_procedur'},
#  {'table_name': u'genes'},
#  {'table_name': u'specimens'},
#  {'table_name': u'fine_structure_searches'},
#  {'table_name': u'facs_population_plans'},
#  {'table_name': u'gene_termini'},
#  {'table_name': u'ncrs'},
#  {'table_name': u'injection_materials'},
#  {'table_name': u'neuronal_model_templates_well_known_files'},
#  {'table_name': u'go_exons'},
#  {'table_name': u'operation_locations'},
#  {'table_name': u'neuronal_models'},
#  {'table_name': u'genomic_objects'},
#  {'table_name': u'scheduled_procedure_notification_reports_scheduled_procedure_no'},
#  {'table_name': u'gene_classifications_genes'},
#  {'table_name': u'scheduled_procedure_notification_criterias_scheduled_procedure_'},
#  {'table_name': u'isi_experiments'},
#  {'table_name': u'assigned_users_scheduled_procedure_notifications'},
#  {'table_name': u'occupations'},
#  {'table_name': u'notification_criteria_types'},
#  {'table_name': u'gene_tags_genes'},
#  {'table_name': u'scheduled_procedure_notification_requested_date_ranges_schedule'},
#  {'table_name': u'unit_of_times'},
#  {'table_name': u'projects_scheduled_procedure_notifications'},
#  {'table_name': u'scheduled_procedure_notifications'},
#  {'table_name': u'informatics_ranking_queries'},
#  {'table_name': u'scheduled_procedure_notification_date_ranges'},
#  {'table_name': u'unit_of_measurements'},
#  {'table_name': u'informatics_ranking_query_results'},
#  {'table_name': u'injection_coordinates'},
#  {'table_name': u'facs_well_templates'},
#  {'table_name': u'job_transitions_scanners'},
#  {'table_name': u'notification_run_frequencies'},
#  {'table_name': u'donor_substances'},
#  {'table_name': u'homology_arms'},
#  {'table_name': u'job_transitions_workflows'},
#  {'table_name': u'notification_criterias'},
#  {'table_name': u'equipment'},
#  {'table_name': u'job_transitions_run_group_types'},
#  {'table_name': u'notification_reports'},
#  {'table_name': u'notification_types'},
#  {'table_name': u'substances'},
#  {'table_name': u'pcr_polymerases'},
#  {'table_name': u'ophys_experiment_tags'},
#  {'table_name': u'eye_trackings'},
#  {'table_name': u'ophys_sessions'},
#  {'table_name': u'imaging_depths'},
#  {'table_name': u'originating_labs'},
#  {'table_name': u'nuclease_activities_pcrs'},
#  {'table_name': u'probe_summary_views'},
#  {'table_name': u'projects_trigger_types'},
#  {'table_name': u'project_well_types'},
#  {'table_name': u'experiment_containers'},
#  {'table_name': u'reference_spaces_workflows'},
#  {'table_name': u'projection_structure_unionizes'},
#  {'table_name': u'probe_refseq_blast_results_v'},
#  {'table_name': u'related_jobs_v'},
#  {'table_name': u'rseq_library_quantification_methods'},
#  {'table_name': u'images'},
#  {'table_name': u'ophys_experiments'},
#  {'table_name': u'rseq_library_prep_sets'},
#  {'table_name': u'sections_slides_mappings'},
#  {'table_name': u'methods_versions_reviewers'},
#  {'table_name': u'sequencing_instruments'},
#  {'table_name': u'medical_condition_types'},
#  {'table_name': u'scheduled_procedures'},
#  {'table_name': u'methods_version_types'},
#  {'table_name': u'slide_registration_states'},
#  {'table_name': u'specimen_tags_specimens'},
#  {'table_name': u'stem_cell_line_sources'},
#  {'table_name': u'stem_cell_line_sources_stem_cell_lines'},
#  {'table_name': u'structure_sets'},
#  {'table_name': u'task_templates_surgical_procedures'},
#  {'table_name': u'talen_pairs'},
#  {'table_name': u'tcp_sops'},
#  {'table_name': u'task_flows'},
#  {'table_name': u'transfection_condition_colony_colors'},
#  {'table_name': u'trigger_types'},
#  {'table_name': u'user_header_elements'},
#  {'table_name': u'view_slide_parent_specimens'},
#  {'table_name': u'heatmap_runs'},
#  {'table_name': u'ephys_cell_plans'},
#  {'table_name': u'rseq_experiment_components_single_cell_analysis_runs'},
#  {'table_name': u'facs_facs_plate_templates'},
#  {'table_name': u'gene_associations'},
#  {'table_name': u'annotationset'},
#  {'table_name': u'classificationsynonym'},
#  {'table_name': u'allseries'},
#  {'table_name': u'structures'},
#  {'table_name': u'dataset'},
#  {'table_name': u'lims2imageseries'},
#  {'table_name': u'measuregroupvaluedefinition'},
#  {'table_name': u'point'},
#  {'table_name': u'class_mappings'},
#  {'table_name': u'clone_sources'},
#  {'table_name': u'clones'},
#  {'table_name': u'probe_fluor_combinations'},
#  {'table_name': u'probe_sets_run_groups'},
#  {'table_name': u'donors'},
#  {'table_name': u'ensembl_genes_v'},
#  {'table_name': u'ext_image_series_v'},
#  {'table_name': u'fluor_colors'},
#  {'table_name': u'freezers'},
#  {'table_name': u'ncbi_genes_v'},
#  {'table_name': u'refseq_human_gff_36'},
#  {'table_name': u'run_group_states'},
#  {'table_name': u'scanners'},
#  {'table_name': u'pg_event_trigger'},
#  {'table_name': u'well_known_files'},
#  {'table_name': u'users_work_groups'},
#  {'table_name': u'units'},
#  {'table_name': u'widgets'},
#  {'table_name': u'thicknesses'},
#  {'table_name': u'users'},
#  {'table_name': u'view_calculate_dilutions'},
#  {'table_name': u'work_groups'},
#  {'table_name': u'pg_attrdef'},
#  {'table_name': u'pg_amop'},
#  {'table_name': u'pg_amproc'},
#  {'table_name': u'pg_language'},
#  {'table_name': u'pg_aggregate'},
#  {'table_name': u'pg_rewrite'},
#  {'table_name': u'pg_trigger'},
#  {'table_name': u'transfection_conditions'},
#  {'table_name': u'treatment_tasks'},
#  {'table_name': u'pg_description'},
#  {'table_name': u'pg_cast'},
#  {'table_name': u'pg_enum'},
#  {'table_name': u'pg_namespace'},
#  {'table_name': u'pg_conversion'},
#  {'table_name': u'pg_database'},
#  {'table_name': u'pg_db_role_setting'},
#  {'table_name': u'pg_tablespace'},
#  {'table_name': u'pg_pltemplate'},
#  {'table_name': u'pg_auth_members'},
#  {'table_name': u'pg_shdepend'},
#  {'table_name': u'pg_shdescription'},
#  {'table_name': u'pg_ts_config'},
#  {'table_name': u'pg_ts_config_map'},
#  {'table_name': u'pg_ts_dict'},
#  {'table_name': u'pg_ts_parser'},
#  {'table_name': u'pg_ts_template'},
#  {'table_name': u'pg_extension'},
#  {'table_name': u'pg_foreign_data_wrapper'},
#  {'table_name': u'pg_foreign_server'},
#  {'table_name': u'pg_foreign_table'},
#  {'table_name': u'pg_default_acl'},
#  {'table_name': u'pg_seclabel'},
#  {'table_name': u'pg_shseclabel'},
#  {'table_name': u'pg_collation'},
#  {'table_name': u'pg_range'},
#  {'table_name': u'sql_implementation_info'},
#  {'table_name': u'pg_class'},
#  {'table_name': u'pg_inherits'},
#  {'table_name': u'sql_features'},
#  {'table_name': u'pg_largeobject_metadata'},
#  {'table_name': u'annotationplan'},
#  {'table_name': u'alignment3ds'},
#  {'table_name': u'annotationplanreport'},
#  {'table_name': u'stringannotation'},
#  {'table_name': u'preupdate'},
#  {'table_name': u'postupdateall'},
#  {'table_name': u'preupdateall'},
#  {'table_name': u'alignment2ds'},
#  {'table_name': u'array_slides'},
#  {'table_name': u'activity_cells'},
#  {'table_name': u'targetentity'},
#  {'table_name': u'annotationplanuser'},
#  {'table_name': u'planregionmap'},
#  {'table_name': u'measuregroup'},
#  {'table_name': u'groupuser'},
#  {'table_name': u'reflabelupdates'},
#  {'table_name': u'buffers'},
#  {'table_name': u'affymetrix_macaque_probesets'},
#  {'table_name': u'atlases_avg_group_labels'},
#  {'table_name': u'atlases'},
#  {'table_name': u'affymetrix_transcript_clusters'},
#  {'table_name': u'cell_descriptions'},
#  {'table_name': u'avg_replicate_types'},
#  {'table_name': u'crisprs_engineering_steps'},
#  {'table_name': u'cell_prep_roi_plans_chemicals'},
#  {'table_name': u'probe_templates'},
#  {'table_name': u'custom_reports'},
#  {'table_name': u'cell_bank_types'},
#  {'table_name': u'cell_prep_roi_plans'},
#  {'table_name': u'crisprs'},
#  {'table_name': u'crisprs_nuclease_activities'},
#  {'table_name': u'sequences'},
#  {'table_name': u'chemicals'},
#  {'table_name': u'behavior_sessions'},
#  {'table_name': u'engineering_drugs'},
#  {'table_name': u'donor_dna_promoter_components'},
#  {'table_name': u'entrez_aliases'},
#  {'table_name': u'ephys_stimulus_set_groups'},
#  {'table_name': u'ensembl_to_ncbi_mappings'},
#  {'table_name': u'donor_dna_recombinases'},
#  {'table_name': u'donor_dna_elements'},
#  {'table_name': u'ephys_specimen_roi_plans'},
#  {'table_name': u'cell_reporters'},
#  {'table_name': u'ephys_pipette_types'},
#  {'table_name': u'donor_dna_recombinase_sites'},
#  {'table_name': u'ephys_sweep_tags'},
#  {'table_name': u'donor_dna_promoters_donor_dna_recombinase_sites'},
#  {'table_name': u'engineering_steps'},
#  {'table_name': u'ephys_neural_tissue_templates_ephys_roi_plans'},
#  {'table_name': u'engineering_step_validations'},
#  {'table_name': u'facs_resources'},
#  {'table_name': u'go_file_types'},
#  {'table_name': u'external_controls'},
#  {'table_name': u'flips'},
#  {'table_name': u'genes_genotypes'},
#  {'table_name': u'genome_loci'},
#  {'table_name': u'header_elements'},
#  {'table_name': u'gene_classifications'},
#  {'table_name': u'go_files'},
#  {'table_name': u'ercc_diluted_pools'},
#  {'table_name': u'file_sources'},
#  {'table_name': u'facs_plate_templates'},
#  {'table_name': u'genders'},
#  {'table_name': u'ercc_stock_pools'},
#  {'table_name': u'mechanical_dissociation_types'},
#  {'table_name': u'injections'},
#  {'table_name': u'job_transitions_structures'},
#  {'table_name': u'injection_materials_injection_templates'},
#  {'table_name': u'pcrs'},
#  {'table_name': u'ish_quality_metrics'},
#  {'table_name': u'locations'},
#  {'table_name': u'nucleases'},
#  {'table_name': u'informatics_ranking_query_types'},
#  {'table_name': u'job_transitions_plane_of_sections'},
#  {'table_name': u'list_configurations'},
#  {'table_name': u'injections_structures'},
#  {'table_name': u'human_chrs_map'},
#  {'table_name': u'injection_qualities'},
#  {'table_name': u'microarray_chipsets'},
#  {'table_name': u'job_transitions_ages'},
#  {'table_name': u'injection_materials_injections'},
#  {'table_name': u'pcrs_southern_blots'},
#  {'table_name': u'pcr_names'},
#  {'table_name': u'reprogramming_methods'},
#  {'table_name': u'registration_points'},
#  {'table_name': u'rs_tubes'},
#  {'table_name': u'rs_alignment_runs'},
#  {'table_name': u'publishes'},
#  {'table_name': u'nuclease_activities_talen_pairs'},
#  {'table_name': u'probe_sources'},
#  {'table_name': u'rseq_oligos'},
#  {'table_name': u'probe_types'},
#  {'table_name': u'rna_seq_experiments'},
#  {'table_name': u'plate_types'},
#  {'table_name': u'rs_tubesets'},
#  {'table_name': u'rna_amplifications'},
#  {'table_name': u'neuronal_model_template_types'},
#  {'table_name': u'rna_amplification_sets'},
#  {'table_name': u'sub_image_annotation_tags'},
#  {'table_name': u'specimen_types'},
#  {'table_name': u'rseq_tube_sets'},
#  {'table_name': u'sub_image_annotations'},
#  {'table_name': u'stimulus_sets'},
#  {'table_name': u'structure_unionizes'},
#  {'table_name': u'sub_image_annotation_tags_sub_image_annotations'},
#  {'table_name': u'rseq_size_selection_inputs'},
#  {'table_name': u'rna_amplification_inputs'},
#  {'table_name': u'stereotaxic_injections_structures'},
#  {'table_name': u'specimen_sets'},
#  {'table_name': u'run_types'},
#  {'table_name': u'sub_image_types'},
#  {'table_name': u'structure_sets_structures'},
#  {'table_name': u'cell_banks'},
#  {'table_name': u'chemical_instances'},
#  {'table_name': u'donor_medical_conditions'},
#  {'table_name': u'talen_pairs_engineering_steps'},
#  {'table_name': u'tissuecyte_calibrations'},
#  {'table_name': u'transfection_methods'},
#  {'table_name': u'transgenic_line_sources'},
#  {'table_name': u'wash_buffer_types'},
#  {'table_name': u'well_types'},
#  {'table_name': u'plates'},
#  {'table_name': u'washes'},
#  {'table_name': u'transgenic_induction_methods'},
#  {'table_name': u'workflows'},
#  {'table_name': u'top_levels'},
#  {'table_name': u'talens'},
#  {'table_name': u'cell_prep_specimen_roi_plans'},
#  {'table_name': u'donor_dna_construct_designs'},
#  {'table_name': u'reference_genomes'},
#  {'table_name': u'tumor_features'},
#  {'table_name': u'neuron_reconstruction_tags_neuron_reconstructions'},
#  {'table_name': u'stem_cell_lines'},
#  {'table_name': u'executables_projects'},
#  {'table_name': u'annotationuser'},
#  {'table_name': u'annotationgroup'},
#  {'table_name': u'classificationitem'},
#  {'table_name': u'annotatedvaluedefinition'},
#  {'table_name': u'annotationproject'},
#  {'table_name': u'classificationitemretired'},
#  {'table_name': u'region'},
#  {'table_name': u'targetentitytype'},
#  {'table_name': u'annotationspace'},
#  {'table_name': u'wells'},
#  {'table_name': u'genomicspreadsheet'},
#  {'table_name': u'allseries4_6'},
#  {'table_name': u'classificationannotation'},
#  {'table_name': u'allseries4_6_2'},
#  {'table_name': u'floatannotation'},
#  {'table_name': u'annotationitem'},
#  {'table_name': u'annotationsetupdates'},
#  {'table_name': u'integerannotation'},
#  {'table_name': u'annotationitemupdates'},
#  {'table_name': u'annotationprojectuser'},
#  {'table_name': u'planregionmapcell'},
#  {'table_name': u'correcttargetentityvalues'},
#  {'table_name': u'groupgroup'},
#  {'table_name': u'regionregion'},
#  {'table_name': u'revisionhistory'},
#  {'table_name': u'ages_executables'},
#  {'table_name': u'archives'},
#  {'table_name': u'death_causes'},
#  {'table_name': u'access_rights'},
#  {'table_name': u'blocks_section_arrangements'},
#  {'table_name': u'slides'},
#  {'table_name': u'chromosomes'},
#  {'table_name': u'vertexset'},
#  {'table_name': u'imageseriesgene'},
#  {'table_name': u'probe_template_batches'},
#  {'table_name': u'avg_replicates'},
#  {'table_name': u'cell_prep_tubes'},
#  {'table_name': u'run_groups'},
#  {'table_name': u'runplans'},
#  {'table_name': u'cell_soma_locations'},
#  {'table_name': u'calculatedilutiontemplate'},
#  {'table_name': u'cloning_vectors'},
#  {'table_name': u'ages'},
#  {'table_name': u'death_manners'},
#  {'table_name': u'probes'},
#  {'table_name': u'transcript_versions'},
#  {'table_name': u'ages_job_transitions'},
#  {'table_name': u'audits'},
#  {'table_name': u'blast_runs'},
#  {'table_name': u'differentiations'},
#  {'table_name': u'donor_dna_promoters'},
#  {'table_name': u'down_sample_job_details'},
#  {'table_name': u'drugs'},
#  {'table_name': u'equalizations'},
#  {'table_name': u'erccs'},
#  {'table_name': u'engineering_steps_helper_plasmids'},
#  {'table_name': u'homologene_groups'},
#  {'table_name': u'engineering_step_component_assemblies'},
#  {'table_name': u'molbio_authorities'},
#  {'table_name': u'projects'},
#  {'table_name': u'runplans_treatments'},
#  {'table_name': u'image_series'},
#  {'table_name': u'plane_of_sections'},
#  {'table_name': u'executables_treatments'},
#  {'table_name': u'equipment_classes'},
#  {'table_name': u'run_group_types'},
#  {'table_name': u'ephys_stimulus_types'},
#  {'table_name': u'donor_dna_recombinases_engineering_steps'},
#  {'table_name': u'drug_instances'},
#  {'table_name': u'education_levels'},
#  {'table_name': u'engineering_step_component_designs'},
#  {'table_name': u'treatments'},
#  {'table_name': u'donor_dna_constructs'},
#  {'table_name': u'gene_symbol_aliases'},
#  {'table_name': u'helper_plasmids'},
#  {'table_name': u'genotypes'},
#  {'table_name': u'gene_classification_categories'},
#  {'table_name': u'image_series_image_series_tags'},
#  {'table_name': u'go_files_specimens'},
#  {'table_name': u'gene_classification_uses'},
#  {'table_name': u'job_transitions'},
#  {'table_name': u'image_series_tags'},
#  {'table_name': u'frozen_media'},
#  {'table_name': u'image_types'},
#  {'table_name': u'jobs'},
#  {'table_name': u'medical_conditions'},
#  {'table_name': u'isi_experiment_tags'},
#  {'table_name': u'job_queues'},
#  {'table_name': u'job_transitions_orientations'},
#  {'table_name': u'job_transitions_projects'},
#  {'table_name': u'file_uploads'},
#  {'table_name': u'gene_histories'},
#  {'table_name': u'heatmap_types'},
#  {'table_name': u'job_transitions_treatments'},
#  {'table_name': u'image_series_slides'},
#  {'table_name': u'isi_experiment_tags_isi_experiments'},
#  {'table_name': u'ldds'},
#  {'table_name': u'neuron_reconstructions'},
#  {'table_name': u'gene_association_sources'},
#  {'table_name': u'neuronal_model_runs'},
#  {'table_name': u'gene_tags'},
#  {'table_name': u'nuclease_activities'},
#  {'table_name': u'schema_migrations'},
#  {'table_name': u'section_arrangements'},
#  {'table_name': u'sections'},
#  {'table_name': u'scans'},
#  {'table_name': u'neuronal_model_templates'},
#  {'table_name': u'slide_groups'},
#  {'table_name': u'rna_to_map_well_mappings'},
#  {'table_name': u'rna_amplification_methods'},
#  {'table_name': u'ophys_experiment_tags_ophys_experiments'},
#  {'table_name': u'ontologies'},
#  {'table_name': u'restriction_enzymes_southern_blots'},
#  {'table_name': u'restriction_enzymes'},
#  {'table_name': u'probe_template_types'},
#  {'table_name': u'orientations'},
#  {'table_name': u'resolutions'},
#  {'table_name': u'rseq_size_selections'},
#  {'table_name': u'probe_sets'},
#  {'table_name': u'probe_results'},
#  {'table_name': u'pcr_confirmation_sequencing_runs'},
#  {'table_name': u'pcr_products'},
#  {'table_name': u'plate_usages'},
#  {'table_name': u'pcr_reaction_types'},
#  {'table_name': u'rseq_size_selection_sets'},
#  {'table_name': u'task_flow_steps_task_templates'},
#  {'table_name': u'rna_seq_analysis_runs_rna_seq_experiments'},
#  {'table_name': u'refseq_homologenes'},
#  {'table_name': u'rseq_library_prep_methods'},
#  {'table_name': u'surgery_orientations'},
#  {'table_name': u'sub_image_qcstate_reasons'},
#  {'table_name': u'races'},
#  {'table_name': u'ephys_features'},
#  {'table_name': u'task_flow_steps'},
#  {'table_name': u'annotationplanvaluedefinition'},
#  {'table_name': u'stimulus_sets_well_known_files'},
#  {'table_name': u'structure_graphs'},
#  {'table_name': u'specimen_preparation_methods'},
#  {'table_name': u'system_settings'},
#  {'table_name': u'biospecimen_polygons'},
#  {'table_name': u'southern_blot_label_types'},
#  {'table_name': u'differentiation_collection_days'},
#  {'table_name': u'cell_samples'},
#  {'table_name': u'template_tags'},
#  {'table_name': u'normalization_groups'},
#  {'table_name': u'gene_classification_sources'},
#  {'table_name': u'slide_tags'},
#  {'table_name': u'sequence_types'},
#  {'table_name': u'blast_alignments'},
#  {'table_name': u'facs_specimens'},
#  {'table_name': u'job_states'},
#  {'table_name': u'primer_reports'},
#  {'table_name': u'slide_tags_slides'},
#  {'table_name': u'source_roles'},
#  {'table_name': u'structure_edges'}]

# %% [markdown]
# ### We can start to find data now and linking between tables

# %% [markdown]
# This is the basics of how a SQL query looks
#
# SELECT TableA., TableB., TableC., TableD. FROM TableA JOIN TableB ON TableB.aID = TableA.aID JOIN TableC ON TableC.cID = TableB.cID WHERE DATE(TableC.date)=date(now())
#
# This allows us to pull in info from 4 different tables since everything we want is not stored in one place, but there are overlaps to link things up. 10 digit IDs generally are your link

# %%
lims_query = "SELECT ephys_roi_results.id, specimens.id, specimens.name \
FROM ephys_roi_results JOIN specimens ON specimens.ephys_roi_result_id = ephys_roi_results.id"
lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#               id                                   name
# 14142  673724358  Ndnf-IRES2-dgCre;Ai14-379866.03.01.01
# 14143  673753671  Slc32a1-IRES-Cre;Ai14-379843.03.02.01
# 14144  673761791  Ndnf-IRES2-dgCre;Ai14-379866.03.01.02
# 14145  673764347  Ndnf-IRES2-dgCre;Ai14-379866.04.02.01
# 14146  673769249  Slc32a1-IRES-Cre;Ai14-379843.03.02.02

# %% [markdown]
# #### This is the structure we want to follow for SQL:

# %% [markdown]
# #### SELECT your tables.columns

# %% [markdown]
# #### FROM these columns are coming if you are going to starting using

# %% [markdown]
# #### JOIN left ON right

# %% [markdown]
# #### WHERE gives you the ability to filter data

# %% [markdown]
# #### AND and OR add variability to your filters

# %% [markdown]
# #### " opens and closes your query"

# %% [markdown]
# #### \ lets you wrap text

# %% [markdown]
# ### We can shorten ephys_roi_results to err and specimens to s, search for all of our features and use

# %% [markdown]
# ### JOIN to join the search results from ephys_roi_results and specimens following the outline from above

# %%
# callout the abreveations in the FROM section
# ephys_roi_results err

lims_query = "SELECT err.id, s.id AS cell_id, s.name \
FROM ephys_roi_results err \
JOIN specimens s ON s.ephys_roi_result_id = err.id"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#          cell_id         id                                   name
# 14142  673724358  673724343  Ndnf-IRES2-dgCre;Ai14-379866.03.01.01
# 14143  673753671  673753609  Slc32a1-IRES-Cre;Ai14-379843.03.02.01
# 14144  673761791  673761757  Ndnf-IRES2-dgCre;Ai14-379866.03.01.02
# 14145  673764347  673764332  Ndnf-IRES2-dgCre;Ai14-379866.04.02.01
# 14146  673769249  673769228  Slc32a1-IRES-Cre;Ai14-379843.03.02.02

# %% [markdown]
# ## Let's add another table and filter data

# %%
#callout the abreveations in the FROM section
# ephys_roi_results err

lims_query = "SELECT err.id, s.id, s.name, proj.code \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
WHERE proj.code = 'H301'"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#      code         id                 name
# 908  H301  643584484  H17.06.013.12.04.01
# 909  H301  643589588  H17.06.013.12.04.02
# 910  H301  643601251  H17.06.013.12.13.01
# 911  H301  643619982  H17.06.013.12.13.02
# 912  H301  643625553  H17.06.013.12.13.03

# %% [markdown]
# ## Things can only get more complicated from here

# %%
lims_query = "SELECT err.id, err.recording_date, err.failed_bad_rs, \
err.failed_electrode_0, err.failed_clogged_pipette, err.failed_no_seal, \
err.failed_other, err.workflow_state, s.name, s.ephys_roi_result_id, s.project_id, proj.id, proj.code \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
WHERE (failed_bad_rs = 'TRUE' \
AND err.failed_electrode_0 = 'FALSE' \
AND err.failed_clogged_pipette = 'FALSE' \
AND err.failed_no_seal = 'FALSE' \
AND err.failed_other = 'FALSE' \
AND err.workflow_state != 'manual_passed') \
AND (proj.code = 'T301' OR proj.code = 'T301x')"

lims_df = get_lims_dataframe(lims_query)
lims_df
# Out:
#     ephys_roi_result_id   code      recording_date  failed_bad_rs  \
# 0             321023255   T301 2015-01-16 15:47:12           True
# 1             322498292   T301 2015-01-22 11:18:24           True
# 2             547274305   T301 2016-09-26 15:58:16           True
# 3             560411917   T301 2016-12-01 13:18:22           True
# 4             562182500   T301 2016-12-22 14:02:19           True
# 5             562724516   T301 2017-01-06 14:20:36           True
# 6             563367964   T301 2017-01-11 14:09:16           True
# 7             563594967   T301 2017-01-12 14:02:43           True
# 8             563596846   T301 2017-01-12 14:18:01           True
# 9             564789700   T301 2017-01-17 14:00:53           True
# 10            565720295   T301 2017-01-20 09:48:46           True
# 11            566457772   T301 2017-01-24 09:15:52           True
# 12            566733619   T301 2017-01-26 11:13:24           True
# 13            566757235   T301 2017-01-26 14:18:45           True
# 14            567040590   T301 2017-01-27 16:12:23           True
# 15            568460493   T301 2017-02-02 10:13:25           True
# 16            568568343   T301 2017-02-02 13:51:39           True
# 17            568766895   T301 2017-02-03 11:03:54           True
# 18            568977879   T301 2017-02-06 11:10:30           True
# 19            570083678   T301 2017-02-17 14:17:33           True
# 20            570297030   T301 2017-02-20 14:24:32           True
# 21            570298262   T301 2017-02-20 14:40:31           True
# 22            571317071   T301 2017-02-27 15:44:40           True
# 23            571392271   T301 2017-02-28 10:13:06           True
# 24            571404951   T301 2017-02-28 10:08:15           True
# 25            571417341   T301 2017-02-28 11:23:01           True
# 26            572827607   T301 2017-03-07 14:27:56           True
# 27            572832222   T301 2017-03-07 14:44:43           True
# 28            573976804   T301 2017-03-13 10:27:55           True
# 29            574056568   T301 2017-03-13 14:56:15           True
# ..                  ...    ...                 ...            ...
# 42            580812829   T301 2017-04-11 09:44:52           True
# 43            580900050   T301 2017-04-11 14:44:26           True
# 44            580901813   T301 2017-04-11 15:21:05           True
# 45            582596021   T301 2017-04-17 09:41:24           True
# 46            582798318   T301 2017-04-18 09:38:05           True
# 47            582854258   T301 2017-04-18 13:19:34           True
# 48            582877712   T301 2017-04-18 14:04:57           True
# 49            583121272   T301 2017-04-19 10:29:01           True
# 50            583294025   T301 2017-04-20 09:51:11           True
# 51            583296877   T301 2017-04-20 09:58:20           True
# 52            584531437   T301 2017-04-25 11:58:22           True
# 53            584947130   T301 2017-04-27 14:27:25           True
# 54            585740025   T301 2017-05-01 09:52:47           True
# 55            587055367   T301 2017-05-05 10:05:15           True
# 56            587083820   T301 2017-05-05 14:05:10           True
# 57            589454075   T301 2017-05-16 22:55:11           True
# 58            589755707   T301 2017-05-17 20:40:20           True
# 59            590562271   T301 2017-05-19 21:03:33           True
# 60            593652011   T301 2017-06-07 21:30:05           True
# 61            594466189   T301 2017-06-09 17:22:50           True
# 62            597517752  T301x 2017-06-23 17:24:35           True
# 63            599440668   T301 2017-06-29 20:30:12           True
# 64            599455399   T301 2017-06-29 21:20:25           True
# 65            599647937   T301 2017-06-30 20:35:34           True
# 66            601800079  T301x 2017-07-10 17:42:03           True
# 67            601831626   T301 2017-07-10 21:03:11           True
# 68            602660919   T301 2017-07-13 22:16:27           True
# 69            604693290  T301x 2017-07-26 22:50:46           True
# 70            605537141  T301x 2017-07-28 20:37:50           True
# 71            605538385  T301x 2017-07-28 21:32:11           True
#
#    workflow_state                                               name  \
# 0   manual_failed                Pvalb-IRES-Cre;Ai14-171555.05.02.01
# 1   manual_failed                  Sst-IRES-Cre;Ai14-172535.03.01.01
# 2   manual_failed    Nos1-CreERT2;Sst-IRES-FlpO;Ai65-271577.06.01.02
# 3   manual_failed           Vip-IRES-Cre;Ai14(IVSCC)-284133.04.01.01
# 4   manual_failed               Htr3a-Cre_NO152;Ai14-288787.04.02.01
# 5   manual_failed                  Vip-IRES-Cre;Ai14-290642.03.02.01
# 6   manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-291491.04.02.01
# 7   manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-291490.03.01.01
# 8   manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-291490.04.01.01
# 9   manual_failed              Ndnf-IRES2-dgCre;Ai14-292674.04.02.01
# 10  manual_failed              Ndnf-IRES2-dgCre;Ai14-294019.03.02.01
# 11  manual_failed        Chrna2-Cre_OE25;Ai14(IVSCC)-294468.04.02.01
# 12  manual_failed                  Nos1-CreERT2;Ai14-294359.06.02.01
# 13  manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-294489.05.02.01
# 14  manual_failed                  Vip-IRES-Cre;Ai14-294014.05.01.01
# 15  manual_failed             Chat-IRES-Cre-neo;Ai14-296443.03.02.01
# 16  manual_failed                Esr2-IRES2-Cre;Ai14-296165.03.02.01
# 17  manual_failed                  Vip-IRES-Cre;Ai14-296357.01.02.01
# 18  manual_failed               Vipr2-IRES2-Cre;Ai14-297026.05.01.01
# 19  manual_failed                  Vip-IRES-Cre;Ai14-298226.04.02.01
# 20  manual_failed             Chat-IRES-Cre-neo;Ai14-299536.03.02.01
# 21  manual_failed             Chat-IRES-Cre-neo;Ai14-299536.03.01.01
# 22  manual_failed                Pvalb-IRES-Cre;Ai14-299809.03.01.01
# 23  manual_failed                Pvalb-IRES-Cre;Ai14-299810.05.01.01
# 24  manual_failed                Pvalb-IRES-Cre;Ai14-299810.03.01.01
# 25  manual_failed                Pvalb-IRES-Cre;Ai14-299810.03.01.02
# 26  manual_failed                Pvalb-IRES-Cre;Ai14-301946.04.01.01
# 27  manual_failed                Pvalb-IRES-Cre;Ai14-301946.03.01.01
# 28  manual_failed                Pvalb-IRES-Cre;Ai14-305769.05.02.01
# 29  manual_failed    Nos1-CreERT2;Sst-IRES-FlpO;Ai65-304714.02.02.01
# ..            ...                                                ...
# 42  manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-311670.04.02.01
# 43  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
# 44  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
# 45  manual_failed             Chat-IRES-Cre-neo;Ai14-313177.03.02.01
# 46  manual_failed             Chat-IRES-Cre-neo;Ai14-313183.04.02.01
# 47  manual_failed             Chat-IRES-Cre-neo;Ai14-313178.03.02.01
# 48  manual_failed             Chat-IRES-Cre-neo;Ai14-313178.03.02.02
# 49  manual_failed        Chrna2-Cre_OE25;Ai14(IVSCC)-312984.04.02.01
# 50  manual_failed             Chat-IRES-Cre-neo;Ai14-313180.04.01.01
# 51  manual_failed             Chat-IRES-Cre-neo;Ai14-313180.03.01.01
# 52  manual_failed                  Vip-IRES-Cre;Ai14-314154.06.02.02
# 53  manual_failed               Htr3a-Cre_NO152;Ai14-314466.04.02.01
# 54  manual_failed  Htr3a-Cre_NO152;Pvalb-T2A-Dre;Ai66-313946.03.0...
# 55  manual_failed             Chat-IRES-Cre-neo;Ai14-316041.03.02.01
# 56  manual_failed             Chat-IRES-Cre-neo;Ai14-316040.04.02.01
# 57  manual_failed               Vipr2-IRES2-Cre;Ai14-319360.04.01.01
# 58  manual_failed                 Sim1-Cre_KJ18;Ai14-318179.03.02.01
# 59  manual_failed               Vipr2-IRES2-Cre;Ai14-316908.05.02.01
# 60  manual_failed                  Vip-IRES-Cre;Ai14-324783.05.02.01
# 61  manual_failed                 Gad2-IRES-Cre;Ai14-324793.02.02.01
# 62  manual_failed               Ntsr1-Cre_GN220;Ai14-327832.05.01.01
# 63  manual_failed                Pvalb-IRES-Cre;Ai14-329704.04.01.01
# 64  manual_failed                Pvalb-IRES-Cre;Ai14-329704.04.01.02
# 65  manual_failed                 Tlx3-Cre_PL56;Ai14-329508.05.02.01
# 66  manual_failed                 Tlx3-Cre_PL56;Ai14-332376.04.02.01
# 67  manual_failed                  Nos1-CreERT2;Ai14-333287.03.01.01
# 68  manual_failed                Scnn1a-Tg2-Cre;Ai14-333165.04.02.01
# 69  manual_failed                Rbp4-Cre_KL100;Ai14-337193.04.02.01
# 70  manual_failed                 Gad2-IRES-Cre;Ai14-336420.04.02.01
# 71  manual_failed                 Gad2-IRES-Cre;Ai14-336420.02.02.01
#
#     failed_clogged_pipette  failed_other  project_id  failed_electrode_0  \
# 0                    False         False   305094322               False
# 1                    False         False   305094322               False
# 2                    False         False   305094322               False
# 3                    False         False   305094322               False
# 4                    False         False   305094322               False
# 5                    False         False   305094322               False
# 6                    False         False   305094322               False
# 7                    False         False   305094322               False
# 8                    False         False   305094322               False
# 9                    False         False   305094322               False
# 10                   False         False   305094322               False
# 11                   False         False   305094322               False
# 12                   False         False   305094322               False
# 13                   False         False   305094322               False
# 14                   False         False   305094322               False
# 15                   False         False   305094322               False
# 16                   False         False   305094322               False
# 17                   False         False   305094322               False
# 18                   False         False   305094322               False
# 19                   False         False   305094322               False
# 20                   False         False   305094322               False
# 21                   False         False   305094322               False
# 22                   False         False   305094322               False
# 23                   False         False   305094322               False
# 24                   False         False   305094322               False
# 25                   False         False   305094322               False
# 26                   False         False   305094322               False
# 27                   False         False   305094322               False
# 28                   False         False   305094322               False
# 29                   False         False   305094322               False
# ..                     ...           ...         ...                 ...
# 42                   False         False   305094322               False
# 43                   False         False   305094322               False
# 44                   False         False   305094322               False
# 45                   False         False   305094322               False
# 46                   False         False   305094322               False
# 47                   False         False   305094322               False
# 48                   False         False   305094322               False
# 49                   False         False   305094322               False
# 50                   False         False   305094322               False
# 51                   False         False   305094322               False
# 52                   False         False   305094322               False
# 53                   False         False   305094322               False
# 54                   False         False   305094322               False
# 55                   False         False   305094322               False
# 56                   False         False   305094322               False
# 57                   False         False   305094322               False
# 58                   False         False   305094322               False
# 59                   False         False   305094322               False
# 60                   False         False   305094322               False
# 61                   False         False   305094322               False
# 62                   False         False   300080300               False
# 63                   False         False   305094322               False
# 64                   False         False   305094322               False
# 65                   False         False   305094322               False
# 66                   False         False   300080300               False
# 67                   False         False   305094322               False
# 68                   False         False   305094322               False
# 69                   False         False   300080300               False
# 70                   False         False   300080300               False
# 71                   False         False   300080300               False
#
#            id  failed_no_seal
# 0   305094322           False
# 1   305094322           False
# 2   305094322           False
# 3   305094322           False
# 4   305094322           False
# 5   305094322           False
# 6   305094322           False
# 7   305094322           False
# 8   305094322           False
# 9   305094322           False
# 10  305094322           False
# 11  305094322           False
# 12  305094322           False
# 13  305094322           False
# 14  305094322           False
# 15  305094322           False
# 16  305094322           False
# 17  305094322           False
# 18  305094322           False
# 19  305094322           False
# 20  305094322           False
# 21  305094322           False
# 22  305094322           False
# 23  305094322           False
# 24  305094322           False
# 25  305094322           False
# 26  305094322           False
# 27  305094322           False
# 28  305094322           False
# 29  305094322           False
# ..        ...             ...
# 42  305094322           False
# 43  305094322           False
# 44  305094322           False
# 45  305094322           False
# 46  305094322           False
# 47  305094322           False
# 48  305094322           False
# 49  305094322           False
# 50  305094322           False
# 51  305094322           False
# 52  305094322           False
# 53  305094322           False
# 54  305094322           False
# 55  305094322           False
# 56  305094322           False
# 57  305094322           False
# 58  305094322           False
# 59  305094322           False
# 60  305094322           False
# 61  305094322           False
# 62  300080300           False
# 63  305094322           False
# 64  305094322           False
# 65  305094322           False
# 66  300080300           False
# 67  305094322           False
# 68  305094322           False
# 69  300080300           False
# 70  300080300           False
# 71  300080300           False
#
# [72 rows x 12 columns]

# %% [markdown]
# # Other Useful Queries

# %% [markdown]
# #### look for all the multipatch cells

# %%
lims_query = "SELECT err.id, err.recording_date, s.name, s.ephys_roi_result_id, proj.code \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
AND proj.code = 'mMPATCH'"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#      ephys_roi_result_id     code         id recording_date  \
# 255            673174542  mMPATCH  673174542           None
# 256            673178228  mMPATCH  673178228           None
# 257            673179586  mMPATCH  673179586           None
# 258            673179600  mMPATCH  673179600           None
# 259            673181959  mMPATCH  673181959           None
#
#                                                   name
# 255  Vip-IRES-Cre;Ai140;Sst-IRES-FlpO;Ai65F-379033....
# 256                     Nr5a1-Cre;Ai14-380236.09.06.01
# 257                     Nr5a1-Cre;Ai14-380236.09.06.02
# 258                     Nr5a1-Cre;Ai14-380236.10.06.01
# 259                     Nr5a1-Cre;Ai14-380236.08.06.01

# %% [markdown]
# #### find the Feature Json files all cells that failed QC only due to high access resistance

# %%
lims_query = "SELECT err.id, err.recording_date, err.failed_bad_rs, \
err.failed_electrode_0, err.failed_clogged_pipette, err.failed_no_seal, \
err.failed_other, err.workflow_state, s.name, s.ephys_roi_result_id, s.project_id, proj.id, proj.code, \
f.storage_directory, f.attachable_id \
FROM ephys_roi_results err JOIN specimens s ON s.ephys_roi_result_id = err.id \
JOIN projects proj ON s.project_id = proj.id \
JOIN well_known_files f ON err.id = f.attachable_id \
WHERE (failed_bad_rs = 'TRUE' \
AND err.failed_electrode_0 = 'FALSE' \
AND err.failed_clogged_pipette = 'FALSE' \
AND err.failed_no_seal = 'FALSE' \
AND err.failed_other = 'FALSE' \
AND err.workflow_state != 'manual_passed') \
AND (proj.code = 'T301' OR proj.code = 'T301x') \
AND f.filename LIKE '%%ephys_features.json'"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#     ephys_roi_result_id  code      recording_date  failed_bad_rs  \
# 40            579497253  T301 2017-04-04 15:22:26           True
# 41            579645792  T301 2017-04-05 12:56:54           True
# 42            580812829  T301 2017-04-11 09:44:52           True
# 43            580900050  T301 2017-04-11 14:44:26           True
# 44            580901813  T301 2017-04-11 15:21:05           True
#
#    workflow_state                                               name  \
# 40  manual_failed               Vipr2-IRES2-Cre;Ai14-310516.06.02.01
# 41  manual_failed              Ndnf-IRES2-dgCre;Ai14-311164.05.02.01
# 42  manual_failed        Nkx2-1-CreERT2;Ai14 (IVSCC)-311670.04.02.01
# 43  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
# 44  manual_failed  Chrna2-Cre_OE25;Pvalb-T2A-Dre;Ai66-309757.05.0...
#
#     attachable_id  failed_clogged_pipette  \
# 40      579497253                   False
# 41      579645792                   False
# 42      580812829                   False
# 43      580900050                   False
# 44      580901813                   False
#
#                                     storage_directory  failed_other  \
# 40  /allen/programs/celltypes/production/mousecell...         False
# 41  /allen/programs/celltypes/production/mousecell...         False
# 42  /allen/programs/celltypes/production/mousecell...         False
# 43  /allen/programs/celltypes/production/mousecell...         False
# 44  /allen/programs/celltypes/production/mousecell...         False
#
#     project_id  failed_electrode_0         id  failed_no_seal
# 40   305094322               False  305094322           False
# 41   305094322               False  305094322           False
# 42   305094322               False  305094322           False
# 43   305094322               False  305094322           False
# 44   305094322               False  305094322           False

# %% [markdown]
# #### find patchseq cells entered in LIMS after Jan. 1, 2017 and their RNA results

# %%
lims_query = "SELECT ra.amplified_quantity_ng, ra.name, ra.run_date, ra.percent_cdna_longer_than_400bp, ra.failed, \
ra.cycles, ra.id, rai.sample_id, cell.id, cell.name, cell.created_at, cell.patched_cell_container \
FROM specimens cell \
LEFT JOIN rna_amplification_inputs rai ON rai.sample_id = cell.id \
LEFT JOIN rna_amplifications ra ON ra.id = rai.rna_amplification_id \
WHERE run_date > '2017-01-01'"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#       amplified_quantity_ng  \
# 3615              10.035892
# 3616              11.284884
# 3617               1.961381
# 3618               4.036444
# 3619               1.539159
#
#                                                    name            run_date  \
# 3615  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-37810... 2018-09-03 07:00:00
# 3616  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-37810... 2018-09-03 07:00:00
# 3617  Crh-IRES-Cre_ZJH;Sst-IRES-FlpO;Ai65-378262.03.... 2018-09-03 07:00:00
# 3618  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-37810... 2018-09-03 07:00:00
# 3619  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-37810... 2018-09-03 07:00:00
#
#       percent_cdna_longer_than_400bp                 created_at  failed  \
# 3615                           0.357 2018-03-07 19:15:41.807285    True
# 3616                           0.688 2018-03-07 21:00:37.056067   False
# 3617                           0.337 2018-03-08 00:35:38.513578    True
# 3618                           0.271 2018-03-07 18:30:36.136546    True
# 3619                           0.317 2018-03-07 18:55:33.062179    True
#
#      patched_cell_container  sample_id  cycles         id
# 3615    P2S4_180307_051_A01  670589879      20  670589879
# 3616    P2S4_180307_052_A01  670666224      20  670666224
# 3617    P2S4_180307_053_A01  670702807      20  670702807
# 3618    P8S4_180307_351_A01  670539587      20  670539587
# 3619    P8S4_180307_352_A01  670568833      20  670568833

# %% [markdown]
# #### find the transgenic line for each cell

# %%
lims_query = "SELECT specimens.name AS cell_name, donors.id, specimens.donor_id, specimens.external_specimen_name, donors.full_genotype, donors.name, specimens.patched_cell_container \
FROM donors JOIN specimens ON specimens.donor_id = donors.id \
WHERE specimens.ephys_roi_result_id IS NOT NULL"

lims_df = get_lims_dataframe(lims_query)
lims_df
# Out:
#                                                    name  \
# 0                                            H16.03.002
# 1        Tlx3-Cre_PL56;Ai140;Vip-IRES-FlpO;Ai65F-378317
# 2                       Slc32a1-IRES2-FlpO;Ai65F-363946
# 3                            Rorb-IRES2-Cre;Ai14-355893
# 4                            Rorb-IRES2-Cre;Ai14-355894
# 5                            Rorb-IRES2-Cre;Ai14-355894
# 6        Tlx3-Cre_PL56;Ai140;Vip-IRES-FlpO;Ai65F-378317
# 7                              Cux2-CreERT2;Ai14-362883
# 8                           Chrna2-Cre_OE25;Ai14-362810
# 9                           Chrna2-Cre_OE25;Ai14-362810
# 10                                           H16.06.004
# 11                                           H16.03.001
# 12                                           H16.06.010
# 13                                           H16.06.006
# 14                          Chrna2-Cre_OE25;Ai14-362810
# 15                                           H15.06.016
# 16                           Pvalb-IRES-Cre;Ai14-310799
# 17                           Rbp4-Cre_KL100;Ai14-337199
# 18                           Rbp4-Cre_KL100;Ai14-357010
# 19                         Slc32a1-IRES-Cre;Ai14-354959
# 20                         Slc32a1-IRES-Cre;Ai14-354959
# 21                        Sim1-Cre_KJ18;Ai14(HZ)-242717
# 22                         Ndnf-IRES2-dgCre;Ai14-280881
# 23                         Ndnf-IRES2-dgCre;Ai14-355226
# 24                            Sim1-Cre_KJ18;Ai14-354911
# 25                            Sim1-Cre_KJ18;Ai14-354911
# 26                            Sim1-Cre_KJ18;Ai14-354917
# 27                            Sim1-Cre_KJ18;Ai14-354917
# 28                          Chrna2-Cre_OE25;Ai14-362806
# 29                          Chrna2-Cre_OE25;Ai14-362806
# ...                                                 ...
# 14117                          Sst-IRES-Cre;Ai14-255916
# 14118                          Sst-IRES-Cre;Ai14-260669
# 14119                          Sst-IRES-Cre;Ai14-260673
# 14120                          Sst-IRES-Cre;Ai14-262492
# 14121                          Sst-IRES-Cre;Ai14-262495
# 14122                          Sst-IRES-Cre;Ai14-263921
# 14123                          Sst-IRES-Cre;Ai14-263921
# 14124                          Sst-IRES-Cre;Ai14-263921
# 14125                        Pvalb-IRES-Cre;Ai14-242137
# 14126                   Vip-IRES-Cre;Ai14(IVSCC)-239490
# 14127                   Vip-IRES-Cre;Ai14(IVSCC)-239490
# 14128                                        H17.03.009
# 14129   Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-358897
# 14130   Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-358898
# 14131   Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-358898
# 14132    Sst-IRES-Cre;Ai140;Pvalb-T2A-FlpO;Ai65F-361318
# 14133                        Vip-IRES-Cre;Ai14-360215.0
# 14134  Slc17a8-IRES2-Cre;Slc32a1-IRES2-FlpO-358882-Ai65
# 14135  Slc17a8-IRES2-Cre;Slc32a1-IRES2-FlpO-358882-Ai65
# 14136                             Nr5a1-Cre;Ai14-350881
# 14137                          Vip-IRES-Cre;Ai14-298227
# 14138                         Gad2-IRES-Cre;Ai14-352686
# 14139                         Gad2-IRES-Cre;Ai14-352686
# 14140            Nos1-CreERT2;Sst-IRES-FlpO;Ai65-377372
# 14141                          Vip-IRES-Cre;Ai14-354376
# 14142                       Chrna2-Cre_OE25;Ai14-355016
# 14143                       Chrna2-Cre_OE25;Ai14-355016
# 14144                        Pvalb-IRES-Cre;Ai14-378390
# 14145                             Nr5a1-Cre;Ai14-378059
# 14146                             Nr5a1-Cre;Ai14-378059
#
#                                            full_genotype  \
# 0                                                   None
# 1          Tlx3-Cre_PL56/wt;Ai140(TIT2L-GFP-ICL-tTA2)/wt
# 2                         Slc32a1-IRES2-FlpO/wt;Ai65F/wt
# 3                     Rorb-IRES2-Cre/wt;Ai14(RCL-tdT)/wt
# 4                     Rorb-IRES2-Cre/wt;Ai14(RCL-tdT)/wt
# 5                     Rorb-IRES2-Cre/wt;Ai14(RCL-tdT)/wt
# 6          Tlx3-Cre_PL56/wt;Ai140(TIT2L-GFP-ICL-tTA2)/wt
# 7                       Cux2-CreERT2/wt;Ai14(RCL-tdT)/wt
# 8                    Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 9                    Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 10                                                  None
# 11                                                  None
# 12                                                  None
# 13                                                  None
# 14                   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 15                                                  None
# 16                    Pvalb-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 17                    Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt
# 18                    Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt
# 19                  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 20                  Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 21                                                  None
# 22                                                  None
# 23                  Ndnf-IRES2-dgCre/wt;Ai14(RCL-tdT)/wt
# 24                     Sim1-Cre_KJ18/wt;Ai14(RCL-tdT)/wt
# 25                     Sim1-Cre_KJ18/wt;Ai14(RCL-tdT)/wt
# 26                     Sim1-Cre_KJ18/wt;Ai14(RCL-tdT)/wt
# 27                     Sim1-Cre_KJ18/wt;Ai14(RCL-tdT)/wt
# 28                   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 29                   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# ...                                                  ...
# 14117                                               None
# 14118                                               None
# 14119                                               None
# 14120                                               None
# 14121                                               None
# 14122                                               None
# 14123                                               None
# 14124                                               None
# 14125                                               None
# 14126                                               None
# 14127                                               None
# 14128                                               None
# 14129  Ndnf-IRES2-dgCre/wt;Slc32a1-IRES2-FlpO/wt;Ai65...
# 14130  Ndnf-IRES2-dgCre/wt;Slc32a1-IRES2-FlpO/wt;Ai65...
# 14131  Ndnf-IRES2-dgCre/wt;Slc32a1-IRES2-FlpO/wt;Ai65...
# 14132  Sst-IRES-Cre/wt;Pvalb-T2A-FlpO/wt;Ai65F/wt;Ai1...
# 14133                   Vip-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14134  Slc17a8-IRES2-Cre/wt;Slc32a1-IRES2-FlpO/wt;Ai6...
# 14135  Slc17a8-IRES2-Cre/wt;Slc32a1-IRES2-FlpO/wt;Ai6...
# 14136                      Nr5a1-Cre/wt;Ai14(RCL-tdT)/wt
# 14137                   Vip-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14138                  Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14139                  Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14140  Nos1-CreERT2/wt;Sst-IRES-FlpO/wt;Ai65(RCFL-tdT...
# 14141                   Vip-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14142                Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 14143                Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 14144                 Pvalb-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14145                      Nr5a1-Cre/wt;Ai14(RCL-tdT)/wt
# 14146                      Nr5a1-Cre/wt;Ai14(RCL-tdT)/wt
#
#       patched_cell_container   donor_id         id external_specimen_name  \
# 0                       None  520276747  520276747                   None
# 1                       None  667489991  667489991                   None
# 2        P8S4_171219_352_A01  652361174  652361174                   None
# 3        P8S4_171023_356_A01  644234836  644234836                   None
# 4        P8S4_171025_351_A01  644234847  644234847                   None
# 5        P8S4_171025_353_A01  644234847  644234847                   None
# 6                       None  667489991  667489991                   None
# 7        P9S4_171208_403_A01  650868847  650868847                   None
# 8        PAS4_171207_454_A01  650869055  650869055                   None
# 9        PAS4_171207_455_A01  650869055  650869055                   None
# 10                      None  504921484  504921484                   None
# 11                      None  518641172  518641172                   None
# 12                      None  529678110  529678110                   None
# 13                      None  517325289  517325289                   None
# 14       PAS4_171207_453_A01  650869055  650869055                   None
# 15                      None  486909083  486909083                   None
# 16                      None  578230819  578230819                   None
# 17       P2S4_170725_051_A01  603513291  603513291                   None
# 18       P8S4_171030_352_A01  644988807  644988807                   None
# 19       P8S4_171025_356_A01  643830358  643830358                   None
# 20       P8S4_171025_355_A01  643830358  643830358                   None
# 21                      None  515045209  515045209                   None
# 22                      None  555257210  555257210                   None
# 23       PAS4_171026_451_A01  643830412  643830412                   None
# 24       P9S4_171030_406_A01  644988729  644988729                   None
# 25       P9S4_171030_405_A01  644988729  644988729                   None
# 26       P2S4_171031_054_A01  644988742  644988742                   None
# 27       P2S4_171031_053_A01  644988742  644988742                   None
# 28       PBS4_171211_503_A01  650868815  650868815                   None
# 29       PBS4_171211_501_A01  650868815  650868815                   None
# ...                      ...        ...        ...                    ...
# 14117                   None  526929158  526929158                   None
# 14118                   None  530227668  530227668                   None
# 14119                   None  530227688  530227688                   None
# 14120                   None  531981731  531981731                   None
# 14121                   None  531981739  531981739                   None
# 14122                   None  538899116  538899116                   None
# 14123                   None  538899116  538899116                   None
# 14124                   None  538899116  538899116                   None
# 14125                   None  512321892  512321892                   None
# 14126                   None  510626803  510626803                   None
# 14127                   None  510626803  510626803                   None
# 14128                   None  596832620  596832620                   None
# 14129    PBS4_171116_503_A01  648085040  648085040                   None
# 14130    P9S4_171115_406_A01  648086990  648086990                   None
# 14131    PBS4_171115_504_A01  648086990  648086990                   None
# 14132                   None  649502932  649502932                   None
# 14133    P9S4_171114_408_A01  647700042  647700042                   None
# 14134    PBS4_171115_507_A01  648085025  648085025                   None
# 14135    P9S4_171115_404_A01  648085025  648085025                   None
# 14136    P2S4_171004_058_A01  639035026  639035026                   None
# 14137                   None  569752592  569752592                   None
# 14138    PBS4_171009_504_A01  640279125  640279125                   None
# 14139    PBS4_171009_503_A01  640279125  640279125                   None
# 14140    P8S4_180306_356_A01  668456846  668456846                   None
# 14141    P8S4_171009_357_A01  640279075  640279075                   None
# 14142    P8S4_171016_355_A01  642979415  642979415                   None
# 14143    P8S4_171016_356_A01  642979415  642979415                   None
# 14144    PBS4_180306_502_A01  668456824  668456824                   None
# 14145                   None  667489947  667489947                   None
# 14146                   None  667489947  667489947                   None
#
#                                                cell_name
# 0                                    H16.03.002.01.06.02
# 1      Tlx3-Cre_PL56;Ai140;Vip-IRES-FlpO;Ai65F-378317...
# 2               Slc32a1-IRES2-FlpO;Ai65F-363946.04.02.02
# 3                    Rorb-IRES2-Cre;Ai14-355893.04.02.01
# 4                    Rorb-IRES2-Cre;Ai14-355894.04.02.01
# 5                    Rorb-IRES2-Cre;Ai14-355894.04.02.03
# 6      Tlx3-Cre_PL56;Ai140;Vip-IRES-FlpO;Ai65F-378317...
# 7                      Cux2-CreERT2;Ai14-362883.03.01.01
# 8                   Chrna2-Cre_OE25;Ai14-362810.05.01.02
# 9                   Chrna2-Cre_OE25;Ai14-362810.05.01.03
# 10                                   H16.06.004.02.03.01
# 11                                   H16.03.001.01.26.01
# 12                                H16.06.010.01.01.11.01
# 13                                   H16.06.006.01.03.03
# 14                  Chrna2-Cre_OE25;Ai14-362810.05.01.01
# 15                                   H15.06.016.01.05.01
# 16                   Pvalb-IRES-Cre;Ai14-310799.03.01.01
# 17                   Rbp4-Cre_KL100;Ai14-337199.03.02.01
# 18                   Rbp4-Cre_KL100;Ai14-357010.05.02.01
# 19                 Slc32a1-IRES-Cre;Ai14-354959.04.02.02
# 20                 Slc32a1-IRES-Cre;Ai14-354959.04.02.01
# 21                Sim1-Cre_KJ18;Ai14(HZ)-242717.06.06.01
# 22                 Ndnf-IRES2-dgCre;Ai14-280881.04.02.01
# 23                 Ndnf-IRES2-dgCre;Ai14-355226.05.02.01
# 24                    Sim1-Cre_KJ18;Ai14-354911.02.01.02
# 25                    Sim1-Cre_KJ18;Ai14-354911.02.01.01
# 26                    Sim1-Cre_KJ18;Ai14-354917.04.02.02
# 27                    Sim1-Cre_KJ18;Ai14-354917.04.02.01
# 28                  Chrna2-Cre_OE25;Ai14-362806.03.01.03
# 29                  Chrna2-Cre_OE25;Ai14-362806.03.01.01
# ...                                                  ...
# 14117                  Sst-IRES-Cre;Ai14-255916.12.06.01
# 14118                  Sst-IRES-Cre;Ai14-260669.08.06.01
# 14119                  Sst-IRES-Cre;Ai14-260673.08.06.01
# 14120                  Sst-IRES-Cre;Ai14-262492.08.06.01
# 14121                  Sst-IRES-Cre;Ai14-262495.07.06.01
# 14122                  Sst-IRES-Cre;Ai14-263921.07.06.01
# 14123                  Sst-IRES-Cre;Ai14-263921.09.06.02
# 14124                  Sst-IRES-Cre;Ai14-263921.09.06.01
# 14125                Pvalb-IRES-Cre;Ai14-242137.06.04.01
# 14126           Vip-IRES-Cre;Ai14(IVSCC)-239490.05.03.01
# 14127           Vip-IRES-Cre;Ai14(IVSCC)-239490.06.04.01
# 14128                                H17.03.009.11.11.03
# 14129  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-35889...
# 14130  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-35889...
# 14131  Ndnf-IRES2-dgCre;Slc32a1-IRES2-FlpO;Ai65-35889...
# 14132  Sst-IRES-Cre;Ai140;Pvalb-T2A-FlpO;Ai65F-361318...
# 14133                  Vip-IRES-Cre;Ai14-360215.05.01.02
# 14134  Slc17a8-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-3588...
# 14135  Slc17a8-IRES2-Cre;Slc32a1-IRES2-FlpO;Ai65-3588...
# 14136                     Nr5a1-Cre;Ai14-350881.04.01.03
# 14137                  Vip-IRES-Cre;Ai14-298227.03.02.01
# 14138                 Gad2-IRES-Cre;Ai14-352686.03.02.02
# 14139                 Gad2-IRES-Cre;Ai14-352686.03.02.01
# 14140    Nos1-CreERT2;Sst-IRES-FlpO;Ai65-377372.06.02.01
# 14141                  Vip-IRES-Cre;Ai14-354376.04.02.01
# 14142               Chrna2-Cre_OE25;Ai14-355016.05.02.01
# 14143               Chrna2-Cre_OE25;Ai14-355016.05.02.02
# 14144                Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 14145                     Nr5a1-Cre;Ai14-378059.10.06.01
# 14146                     Nr5a1-Cre;Ai14-378059.11.06.01
#
# [14147 rows x 7 columns]

# %% [markdown]
# ## How can I easily add to another dataframe (like the metadata in the Google Doc)?

# %% [markdown]
# #### df_new = pd.merge(left = df_1, right = df_2, left_on = column_from_left, right_on = column_from_right, how = 'inner')

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2017/03/join-types-merge-names.jpg")
# Out:
# <img src="https://shanelynnwebsite-mid9n9g1q9y8tt.netdna-ssl.com/wp-content/uploads/2017/03/join-types-merge-names.jpg"/>

# %%
home = pathlib2.Path.home()
full_path = home/"documents"/"stash"/"ps-metadata-analysis"/"data"/"patch_seq_log_mouse.csv"
full_path = str(full_path)
full_path
initial = pd.read_csv(full_path)

# %%
ps = initial[['cell type', 'File', 'Post patch?', 'Post patch pipette R' , 'PCR cycles', 'SM_QC_PF', 'Bad dates','Lims tube id']]
#ps["Slice (Lims ID?)"].str.strip()

# %%
ps['Bad dates'] = ps['Bad dates'].astype('category')
ps['PCR cycles'] = ps['PCR cycles'].astype('category')
ps['cell type'] = ps['cell type'].astype('category')
ps['Post patch?'] = ps['Post patch?'].astype('category')
ps = ps[ps['Bad dates'] != 'x']
ps = ps[ps['SM_QC_PF'] != 'cnt']
ps = ps[ps['cell type'] == 'tdt+']
ps.dropna(subset = ['Post patch?', 'SM_QC_PF'], inplace = True)

ps = ps.drop('Bad dates', 1)
ps = ps.drop('SM_QC_PF', 1)
ps = ps.drop('PCR cycles', 1)
ps = ps.drop('cell type', 1)
ps.head()
# Out:
#                                    File  Post patch?  Post patch pipette R  \
# 70  Rbp4-Cre_KL100;Ai14-290392.04.02.01  Outside-Out                   NaN
# 71  Rbp4-Cre_KL100;Ai14-290392.04.02.02  Outside-Out                   NaN
# 77  Rbp4-Cre_KL100;Ai14-290393.03.02.01  Outside-Out                   NaN
# 78  Rbp4-Cre_KL100;Ai14-290393.03.02.02  Outside-Out                   NaN
# 79  Rbp4-Cre_KL100;Ai14-290393.04.02.01      No-Seal                   NaN
#
#            Lims tube id
# 70  P2S4_170109_051_A01
# 71  P2S4_170109_052_A01
# 77  P2S4_170110_051_A01
# 78  P2S4_170110_052_A01
# 79  P2S4_170110_053_A01

# %%
new_df = pd.merge(left = ps, right = lims_df, left_on = 'File', right_on = 'cell_name', how = 'left')

# %%
new_df
# Out:
#                                        File      Post patch?  \
# 0       Rbp4-Cre_KL100;Ai14-290392.04.02.01      Outside-Out
# 1       Rbp4-Cre_KL100;Ai14-290392.04.02.02      Outside-Out
# 2       Rbp4-Cre_KL100;Ai14-290393.03.02.01      Outside-Out
# 3       Rbp4-Cre_KL100;Ai14-290393.03.02.02      Outside-Out
# 4       Rbp4-Cre_KL100;Ai14-290393.04.02.01          No-Seal
# 5       Rbp4-Cre_KL100;Ai14-290393.04.02.02      Outside-Out
# 6       Rbp4-Cre_KL100;Ai14-290393.04.02.03      Outside-Out
# 7       Rbp4-Cre_KL100;Ai14-290393.04.02.04      Outside-Out
# 8        Gad2-IRES-Cre;Ai14-293418.06.01.01          No-Seal
# 9        Gad2-IRES-Cre;Ai14-293418.06.01.02  Partial-Nucleus
# 10       Gad2-IRES-Cre;Ai14-293418.06.01.03          No-Seal
# 11       Gad2-IRES-Cre;Ai14-293418.06.02.01  Partial-Nucleus
# 12       Gad2-IRES-Cre;Ai14-293418.06.02.02          No-Seal
# 13       Gad2-IRES-Cre;Ai14-293418.06.02.03          No-Seal
# 14       Gad2-IRES-Cre;Ai14-293418.07.01.01      Outside-Out
# 15       Gad2-IRES-Cre;Ai14-293418.07.02.01      Outside-Out
# 16       Gad2-IRES-Cre;Ai14-293418.07.02.02          No-Seal
# 17       Gad2-IRES-Cre;Ai14-293418.07.02.03      Outside-Out
# 18    Slc32a1-IRES-Cre;Ai14-294507.07.01.01        Nucleated
# 19    Slc32a1-IRES-Cre;Ai14-294507.07.01.02      Outside-Out
# 20    Slc32a1-IRES-Cre;Ai14-294507.07.01.03      Outside-Out
# 21    Slc32a1-IRES-Cre;Ai14-294507.08.01.01        Nucleated
# 22    Slc32a1-IRES-Cre;Ai14-294507.08.01.02          No-Seal
# 23    Slc32a1-IRES-Cre;Ai14-294507.08.01.03      Outside-Out
# 24    Slc32a1-IRES-Cre;Ai14-294507.08.01.04          No-Seal
# 25                            brl_170112_01        Nucleated
# 26                            brl_170112_02      Outside-Out
# 27                            brl_170112_03        Nucleated
# 28       Gad2-IRES-Cre;Ai14-293416.06.01.01      Outside-Out
# 29       Gad2-IRES-Cre;Ai14-293416.06.01.02      Outside-Out
# ...                                     ...              ...
# 2329   Chrna2-Cre_OE25;Ai14-363000.04.01.01   nucleus_absent
# 2330   Chrna2-Cre_OE25;Ai14-363000.04.01.02   nucleus_absent
# 2331   Chrna2-Cre_OE25;Ai14-363000.05.01.01   nucleus_absent
# 2332     Gad2-IRES-Cre;Ai14-362150.04.01.01  nucleus_present
# 2333   Chrna2-Cre_OE25;Ai14-362805.04.01.01  nucleus_present
# 2334   Chrna2-Cre_OE25;Ai14-362805.04.01.02  nucleus_present
# 2335   Chrna2-Cre_OE25;Ai14-363000.05.02.01   nucleus_absent
# 2336   Chrna2-Cre_OE25;Ai14-363000.03.02.01  nucleus_present
# 2337   Chrna2-Cre_OE25;Ai14-362805.03.01.01   nucleus_absent
# 2338   Vipr2-IRES2-Cre;Ai14-360542.04.02.01   nucleus_absent
# 2339   Chrna2-Cre_OE25;Ai14-362809.05.02.01  nucleus_present
# 2340   Chrna2-Cre_OE25;Ai14-362809.03.01.01  nucleus_present
# 2341      Cux2-CreERT2;Ai14-362884.03.01.01   nucleus_absent
# 2342      Cux2-CreERT2;Ai14-362884.03.01.02   nucleus_absent
# 2343   Vipr2-IRES2-Cre;Ai14-359786.04.01.01  nucleus_present
# 2344   Vipr2-IRES2-Cre;Ai14-359786.04.01.02   nucleus_absent
# 2345     Gad2-IRES-Cre;Ai14-362149.05.01.01  nucleus_present
# 2346     Gad2-IRES-Cre;Ai14-362149.05.01.02  nucleus_present
# 2347     Gad2-IRES-Cre;Ai14-362149.05.01.03  nucleus_present
# 2348     Gad2-IRES-Cre;Ai14-362149.04.01.01  nucleus_present
# 2349   Chrna2-Cre_OE25;Ai14-362996.04.02.01  nucleus_present
# 2350   Chrna2-Cre_OE25;Ai14-362996.04.01.01  nucleus_present
# 2351     Gad2-IRES-Cre;Ai14-362149.06.02.01  nucleus_present
# 2352     Gad2-IRES-Cre;Ai14-362149.06.01.01  nucleus_present
# 2353   Vipr2-IRES2-Cre;Ai14-359786.03.01.02  nucleus_present
# 2354   Vipr2-IRES2-Cre;Ai14-359786.03.01.03  nucleus_present
# 2355     Gad2-IRES-Cre;Ai14-362149.04.02.01   nucleus_absent
# 2356     Gad2-IRES-Cre;Ai14-362149.05.02.01  nucleus_present
# 2357     Gad2-IRES-Cre;Ai14-362149.05.02.02  nucleus_present
# 2358     Gad2-IRES-Cre;Ai14-362149.03.02.01  nucleus_present
#
#       Post patch pipette R         Lims tube id                          name  \
# 0                      NaN  P2S4_170109_051_A01    Rbp4-Cre_KL100;Ai14-290392
# 1                      NaN  P2S4_170109_052_A01    Rbp4-Cre_KL100;Ai14-290392
# 2                      NaN  P2S4_170110_051_A01    Rbp4-Cre_KL100;Ai14-290393
# 3                      NaN  P2S4_170110_052_A01    Rbp4-Cre_KL100;Ai14-290393
# 4                      NaN  P2S4_170110_053_A01    Rbp4-Cre_KL100;Ai14-290393
# 5                      NaN  P2S4_170110_054_A01    Rbp4-Cre_KL100;Ai14-290393
# 6                      NaN  P2S4_170110_055_A01    Rbp4-Cre_KL100;Ai14-290393
# 7                      NaN  P2S4_170110_056_A01    Rbp4-Cre_KL100;Ai14-290393
# 8                      NaN  P1S4_170111_001_A01     Gad2-IRES-Cre;Ai14-293418
# 9                      NaN  P1S4_170111_002_A01     Gad2-IRES-Cre;Ai14-293418
# 10                     NaN  P1S4_170111_003_A01     Gad2-IRES-Cre;Ai14-293418
# 11                     NaN  P1S4_170111_004_A01     Gad2-IRES-Cre;Ai14-293418
# 12                     NaN  P1S4_170111_005_A01     Gad2-IRES-Cre;Ai14-293418
# 13                     NaN  P1S4_170111_006_A01     Gad2-IRES-Cre;Ai14-293418
# 14                     NaN  P2S4_170111_051_A01     Gad2-IRES-Cre;Ai14-293418
# 15                     NaN  P2S4_170111_052_A01     Gad2-IRES-Cre;Ai14-293418
# 16                     NaN  P2S4_170111_053_A01     Gad2-IRES-Cre;Ai14-293418
# 17                     NaN  P2S4_170111_054_A01     Gad2-IRES-Cre;Ai14-293418
# 18                     NaN  P1S4_170112_001_A01  Slc32a1-IRES-Cre;Ai14-294507
# 19                     NaN  P1S4_170112_002_A01  Slc32a1-IRES-Cre;Ai14-294507
# 20                     NaN  P1S4_170112_003_A01  Slc32a1-IRES-Cre;Ai14-294507
# 21                     NaN  P1S4_170112_004_A01  Slc32a1-IRES-Cre;Ai14-294507
# 22                     NaN  P1S4_170112_005_A01  Slc32a1-IRES-Cre;Ai14-294507
# 23                     NaN  P1S4_170112_006_A01  Slc32a1-IRES-Cre;Ai14-294507
# 24                     NaN  P1S4_170112_007_A01  Slc32a1-IRES-Cre;Ai14-294507
# 25                     NaN  P3S4_170112_101_A01                           NaN
# 26                     NaN  P3S4_170112_102_A01                           NaN
# 27                     NaN  P3S4_170112_103_A01                           NaN
# 28                     NaN  P1S4_170113_001_A01     Gad2-IRES-Cre;Ai14-293416
# 29                     NaN  P1S4_170113_002_A01     Gad2-IRES-Cre;Ai14-293416
# ...                    ...                  ...                           ...
# 2329                   7.2  P9S4_171204_401_A01   Chrna2-Cre_OE25;Ai14-363000
# 2330                2000.0  P9S4_171204_402_A01   Chrna2-Cre_OE25;Ai14-363000
# 2331                 600.0  P9S4_171204_403_A01   Chrna2-Cre_OE25;Ai14-363000
# 2332                2000.0  P9S4_171204_404_A01     Gad2-IRES-Cre;Ai14-362150
# 2333                3000.0  P9S4_171204_405_A01   Chrna2-Cre_OE25;Ai14-362805
# 2334                2000.0  P9S4_171204_406_A01   Chrna2-Cre_OE25;Ai14-362805
# 2335                   6.2  PAS4_171204_451_A01   Chrna2-Cre_OE25;Ai14-363000
# 2336                 200.0  PBS4_171204_501_A01   Chrna2-Cre_OE25;Ai14-363000
# 2337                 200.0  PBS4_171204_502_A01   Chrna2-Cre_OE25;Ai14-362805
# 2338                   0.0  PBS4_171204_503_A01   Vipr2-IRES2-Cre;Ai14-360542
# 2339                1000.0  PAS4_171205_451_A01   Chrna2-Cre_OE25;Ai14-362809
# 2340                1000.0  PBS4_171205_501_A01   Chrna2-Cre_OE25;Ai14-362809
# 2341                  15.0  P9S4_171206_401_A01      Cux2-CreERT2;Ai14-362884
# 2342                   9.0  P9S4_171206_402_A01      Cux2-CreERT2;Ai14-362884
# 2343                2000.0  P9S4_171206_403_A01   Vipr2-IRES2-Cre;Ai14-359786
# 2344                  21.0  P9S4_171206_404_A01   Vipr2-IRES2-Cre;Ai14-359786
# 2345                1500.0  P9S4_171206_405_A01     Gad2-IRES-Cre;Ai14-362149
# 2346                1000.0  P9S4_171206_406_A01     Gad2-IRES-Cre;Ai14-362149
# 2347                2000.0  P9S4_171206_407_A01     Gad2-IRES-Cre;Ai14-362149
# 2348                2000.0  P9S4_171206_408_A01     Gad2-IRES-Cre;Ai14-362149
# 2349                1000.0  PAS4_171206_451_A01   Chrna2-Cre_OE25;Ai14-362996
# 2350                2000.0  PAS4_171206_452_A01   Chrna2-Cre_OE25;Ai14-362996
# 2351                1000.0  PAS4_171206_453_A01     Gad2-IRES-Cre;Ai14-362149
# 2352                   3.7  PAS4_171206_454_A01     Gad2-IRES-Cre;Ai14-362149
# 2353                 250.0  P6S4_171206_255_A01   Vipr2-IRES2-Cre;Ai14-359786
# 2354                 300.0  P6S4_171206_256_A01   Vipr2-IRES2-Cre;Ai14-359786
# 2355                 200.0  PBS4_171206_504_A01     Gad2-IRES-Cre;Ai14-362149
# 2356                 700.0  PBS4_171206_505_A01     Gad2-IRES-Cre;Ai14-362149
# 2357                   0.0  PBS4_171206_506_A01     Gad2-IRES-Cre;Ai14-362149
# 2358                1000.0  PBS4_171206_507_A01     Gad2-IRES-Cre;Ai14-362149
#
#                              full_genotype patched_cell_container  \
# 0       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170109_051_A01
# 1       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170109_052_A01
# 2       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_051_A01
# 3       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_052_A01
# 4       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_053_A01
# 5       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_054_A01
# 6       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_055_A01
# 7       Rbp4-Cre_KL100/wt;Ai14(RCL-tdT)/wt    P2S4_170110_056_A01
# 8        Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_001_A01
# 9        Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_002_A01
# 10       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_003_A01
# 11       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_004_A01
# 12       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_005_A01
# 13       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170111_006_A01
# 14       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P2S4_170111_051_A01
# 15       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P2S4_170111_052_A01
# 16       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P2S4_170111_053_A01
# 17       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P2S4_170111_054_A01
# 18    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_001_A01
# 19    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_002_A01
# 20    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_003_A01
# 21    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_004_A01
# 22    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_005_A01
# 23    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_006_A01
# 24    Slc32a1-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170112_007_A01
# 25                                     NaN                    NaN
# 26                                     NaN                    NaN
# 27                                     NaN                    NaN
# 28       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170113_001_A01
# 29       Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P1S4_170113_002_A01
# ...                                    ...                    ...
# 2329   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    P9S4_171204_401_A01
# 2330   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    P9S4_171204_402_A01
# 2331   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    P9S4_171204_403_A01
# 2332     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171204_404_A01
# 2333   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    P9S4_171204_405_A01
# 2334   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    P9S4_171204_406_A01
# 2335   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PAS4_171204_451_A01
# 2336   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PBS4_171204_501_A01
# 2337   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PBS4_171204_502_A01
# 2338   Vipr2-IRES2-Cre/wt;Ai14(RCL-tdT)/wt    PBS4_171204_503_A01
# 2339   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PAS4_171205_451_A01
# 2340   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PBS4_171205_501_A01
# 2341      Cux2-CreERT2/wt;Ai14(RCL-tdT)/wt    P9S4_171206_401_A01
# 2342      Cux2-CreERT2/wt;Ai14(RCL-tdT)/wt    P9S4_171206_402_A01
# 2343   Vipr2-IRES2-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_403_A01
# 2344   Vipr2-IRES2-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_404_A01
# 2345     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_405_A01
# 2346     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_406_A01
# 2347     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_407_A01
# 2348     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    P9S4_171206_408_A01
# 2349   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PAS4_171206_451_A01
# 2350   Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt    PAS4_171206_452_A01
# 2351     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PAS4_171206_453_A01
# 2352     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PAS4_171206_454_A01
# 2353   Vipr2-IRES2-Cre/wt;Ai14(RCL-tdT)/wt    P6S4_171206_255_A01
# 2354   Vipr2-IRES2-Cre/wt;Ai14(RCL-tdT)/wt    P6S4_171206_256_A01
# 2355     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PBS4_171206_504_A01
# 2356     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PBS4_171206_505_A01
# 2357     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PBS4_171206_506_A01
# 2358     Gad2-IRES-Cre/wt;Ai14(RCL-tdT)/wt    PBS4_171206_507_A01
#
#          donor_id           id external_specimen_name  \
# 0     562588746.0  562588746.0                   None
# 1     562588746.0  562588746.0                   None
# 2     562588779.0  562588779.0                   None
# 3     562588779.0  562588779.0                   None
# 4     562588779.0  562588779.0                   None
# 5     562588779.0  562588779.0                   None
# 6     562588779.0  562588779.0                   None
# 7     562588779.0  562588779.0                   None
# 8     562377197.0  562377197.0                   None
# 9     562377197.0  562377197.0                   None
# 10    562377197.0  562377197.0                   None
# 11    562377197.0  562377197.0                   None
# 12    562377197.0  562377197.0                   None
# 13    562377197.0  562377197.0                   None
# 14    562377197.0  562377197.0                   None
# 15    562377197.0  562377197.0                   None
# 16    562377197.0  562377197.0                   None
# 17    562377197.0  562377197.0                   None
# 18    562377205.0  562377205.0                   None
# 19    562377205.0  562377205.0                   None
# 20    562377205.0  562377205.0                   None
# 21    562377205.0  562377205.0                   None
# 22    562377205.0  562377205.0                   None
# 23    562377205.0  562377205.0                   None
# 24    562377205.0  562377205.0                   None
# 25            NaN          NaN                    NaN
# 26            NaN          NaN                    NaN
# 27            NaN          NaN                    NaN
# 28    562377193.0  562377193.0                   None
# 29    562377193.0  562377193.0                   None
# ...           ...          ...                    ...
# 2329  650869085.0  650869085.0                   None
# 2330  650869085.0  650869085.0                   None
# 2331  650869085.0  650869085.0                   None
# 2332  650868795.0  650868795.0                   None
# 2333  650868805.0  650868805.0                   None
# 2334  650868805.0  650868805.0                   None
# 2335  650869085.0  650869085.0                   None
# 2336  650869085.0  650869085.0                   None
# 2337  650868805.0  650868805.0                   None
# 2338  650869035.0  650869035.0                   None
# 2339  650868825.0  650868825.0                   None
# 2340  650868825.0  650868825.0                   None
# 2341  650868857.0  650868857.0                   None
# 2342  650868857.0  650868857.0                   None
# 2343  650868765.0  650868765.0                   None
# 2344  650868765.0  650868765.0                   None
# 2345  650868785.0  650868785.0                   None
# 2346  650868785.0  650868785.0                   None
# 2347  650868785.0  650868785.0                   None
# 2348  650868785.0  650868785.0                   None
# 2349  650869075.0  650869075.0                   None
# 2350  650869075.0  650869075.0                   None
# 2351  650868785.0  650868785.0                   None
# 2352  650868785.0  650868785.0                   None
# 2353  650868765.0  650868765.0                   None
# 2354  650868765.0  650868765.0                   None
# 2355  650868785.0  650868785.0                   None
# 2356  650868785.0  650868785.0                   None
# 2357  650868785.0  650868785.0                   None
# 2358  650868785.0  650868785.0                   None
#
#                                   cell_name
# 0       Rbp4-Cre_KL100;Ai14-290392.04.02.01
# 1       Rbp4-Cre_KL100;Ai14-290392.04.02.02
# 2       Rbp4-Cre_KL100;Ai14-290393.03.02.01
# 3       Rbp4-Cre_KL100;Ai14-290393.03.02.02
# 4       Rbp4-Cre_KL100;Ai14-290393.04.02.01
# 5       Rbp4-Cre_KL100;Ai14-290393.04.02.02
# 6       Rbp4-Cre_KL100;Ai14-290393.04.02.03
# 7       Rbp4-Cre_KL100;Ai14-290393.04.02.04
# 8        Gad2-IRES-Cre;Ai14-293418.06.01.01
# 9        Gad2-IRES-Cre;Ai14-293418.06.01.02
# 10       Gad2-IRES-Cre;Ai14-293418.06.01.03
# 11       Gad2-IRES-Cre;Ai14-293418.06.02.01
# 12       Gad2-IRES-Cre;Ai14-293418.06.02.02
# 13       Gad2-IRES-Cre;Ai14-293418.06.02.03
# 14       Gad2-IRES-Cre;Ai14-293418.07.01.01
# 15       Gad2-IRES-Cre;Ai14-293418.07.02.01
# 16       Gad2-IRES-Cre;Ai14-293418.07.02.02
# 17       Gad2-IRES-Cre;Ai14-293418.07.02.03
# 18    Slc32a1-IRES-Cre;Ai14-294507.07.01.01
# 19    Slc32a1-IRES-Cre;Ai14-294507.07.01.02
# 20    Slc32a1-IRES-Cre;Ai14-294507.07.01.03
# 21    Slc32a1-IRES-Cre;Ai14-294507.08.01.01
# 22    Slc32a1-IRES-Cre;Ai14-294507.08.01.02
# 23    Slc32a1-IRES-Cre;Ai14-294507.08.01.03
# 24    Slc32a1-IRES-Cre;Ai14-294507.08.01.04
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28       Gad2-IRES-Cre;Ai14-293416.06.01.01
# 29       Gad2-IRES-Cre;Ai14-293416.06.01.02
# ...                                     ...
# 2329   Chrna2-Cre_OE25;Ai14-363000.04.01.01
# 2330   Chrna2-Cre_OE25;Ai14-363000.04.01.02
# 2331   Chrna2-Cre_OE25;Ai14-363000.05.01.01
# 2332     Gad2-IRES-Cre;Ai14-362150.04.01.01
# 2333   Chrna2-Cre_OE25;Ai14-362805.04.01.01
# 2334   Chrna2-Cre_OE25;Ai14-362805.04.01.02
# 2335   Chrna2-Cre_OE25;Ai14-363000.05.02.01
# 2336   Chrna2-Cre_OE25;Ai14-363000.03.02.01
# 2337   Chrna2-Cre_OE25;Ai14-362805.03.01.01
# 2338   Vipr2-IRES2-Cre;Ai14-360542.04.02.01
# 2339   Chrna2-Cre_OE25;Ai14-362809.05.02.01
# 2340   Chrna2-Cre_OE25;Ai14-362809.03.01.01
# 2341      Cux2-CreERT2;Ai14-362884.03.01.01
# 2342      Cux2-CreERT2;Ai14-362884.03.01.02
# 2343   Vipr2-IRES2-Cre;Ai14-359786.04.01.01
# 2344   Vipr2-IRES2-Cre;Ai14-359786.04.01.02
# 2345     Gad2-IRES-Cre;Ai14-362149.05.01.01
# 2346     Gad2-IRES-Cre;Ai14-362149.05.01.02
# 2347     Gad2-IRES-Cre;Ai14-362149.05.01.03
# 2348     Gad2-IRES-Cre;Ai14-362149.04.01.01
# 2349   Chrna2-Cre_OE25;Ai14-362996.04.02.01
# 2350   Chrna2-Cre_OE25;Ai14-362996.04.01.01
# 2351     Gad2-IRES-Cre;Ai14-362149.06.02.01
# 2352     Gad2-IRES-Cre;Ai14-362149.06.01.01
# 2353   Vipr2-IRES2-Cre;Ai14-359786.03.01.02
# 2354   Vipr2-IRES2-Cre;Ai14-359786.03.01.03
# 2355     Gad2-IRES-Cre;Ai14-362149.04.02.01
# 2356     Gad2-IRES-Cre;Ai14-362149.05.02.01
# 2357     Gad2-IRES-Cre;Ai14-362149.05.02.02
# 2358     Gad2-IRES-Cre;Ai14-362149.03.02.01
#
# [2359 rows x 11 columns]

# %%
lims_query = "SELECT name, barcode FROM specimens \
WHERE specimens.ephys_roi_result_id IS NOT NULL"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#           barcode                                  name
# 14142  0643511562  Chrna2-Cre_OE25;Ai14-355016.05.02.01
# 14143  0643518188  Chrna2-Cre_OE25;Ai14-355016.05.02.02
# 14144  0670343682   Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 14145  0669864819        Nr5a1-Cre;Ai14-378059.10.06.01
# 14146  0669865467        Nr5a1-Cre;Ai14-378059.11.06.01

# %%
lims_query = "SELECT specimens.name as cell_name, specimens.barcode, specimens.donor_id, donors.id \
FROM specimens JOIN donors ON specimens.donor_id = donors.id \
WHERE specimens.ephys_roi_result_id IS NOT NULL"

df = get_lims_dataframe(lims_query)
df.tail()
# Out:
#           barcode   donor_id         id                             cell_name
# 14142  0643511562  642979415  642979415  Chrna2-Cre_OE25;Ai14-355016.05.02.01
# 14143  0643518188  642979415  642979415  Chrna2-Cre_OE25;Ai14-355016.05.02.02
# 14144  0670343682  668456824  668456824   Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 14145  0669864819  667489947  667489947        Nr5a1-Cre;Ai14-378059.10.06.01
# 14146  0669865467  667489947  667489947        Nr5a1-Cre;Ai14-378059.11.06.01

# %%
lims_query = "SELECT cell.name as cell_name, donors.full_genotype, cell.donor_id, donors.id \
FROM specimens cell JOIN donors ON cell.donor_id = donors.id \
WHERE cell.ephys_roi_result_id IS NOT NULL"

lims_df = get_lims_dataframe(lims_query)
lims_df.tail()
# Out:
#         donor_id         id                        full_genotype  \
# 14142  642979415  642979415  Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 14143  642979415  642979415  Chrna2-Cre_OE25/wt;Ai14(RCL-tdT)/wt
# 14144  668456824  668456824   Pvalb-IRES-Cre/wt;Ai14(RCL-tdT)/wt
# 14145  667489947  667489947        Nr5a1-Cre/wt;Ai14(RCL-tdT)/wt
# 14146  667489947  667489947        Nr5a1-Cre/wt;Ai14(RCL-tdT)/wt
#
#                                   cell_name
# 14142  Chrna2-Cre_OE25;Ai14-355016.05.02.01
# 14143  Chrna2-Cre_OE25;Ai14-355016.05.02.02
# 14144   Pvalb-IRES-Cre;Ai14-378390.04.02.01
# 14145        Nr5a1-Cre;Ai14-378059.10.06.01
# 14146        Nr5a1-Cre;Ai14-378059.11.06.01

# %% [markdown]
# ### How many cells took longer to find instantaneous threshold than they did to find rheobase(ie more SSFINEST than LSFINEST sweeps

# %%
lims_query = "SELECT specimens.name AS cell_name, \
COUNT (CASE WHEN ephys_stimuli.description LIKE '%%C1SSFINEST150112%%' THEN 1 ELSE NULL END) AS shortsquare, \
COUNT (CASE WHEN ephys_stimuli.description LIKE '%%C1LSFINEST150112%%' THEN 1 ELSE NULL END) AS longsquare \
FROM specimens JOIN ephys_sweeps ON specimens.id = ephys_sweeps.specimen_id \
JOIN ephys_stimuli ON ephys_sweeps.ephys_stimulus_id = ephys_stimuli.id \
WHERE specimens.patched_cell_container NOTNULL \
GROUP BY specimens.name"

df = get_lims_dataframe(lims_query)
df = df.query('shortsquare > longsquare') 
len(df)
#df.head()
# Out:
# 3393

# %% [markdown]
# ### Show the distribution of hemispheres all the cells patched in 2017 with the age and sex of the mice used.

# %%
lims_query = "SELECT specimens.name AS cell_name, err.recording_date AS date, donors.age_id, donors.gender_id \
FROM specimens JOIN donors ON specimens.donor_id = donors.id \
JOIN ephys_roi_results err ON specimens.ephys_roi_result_id = err.id \
WHERE specimens.ephys_roi_result_id IS NOT NULL and err.recording_date IS NOT NULL"

df = get_lims_dataframe(lims_query)
df['Year'] = pd.DatetimeIndex(df['date']).year
df = df[df['Year'] == 2017]
df.loc[df.cell_name.str.endswith('.01'), 'Hemi'] = 'Left'
df.loc[df.cell_name.str.endswith('.02'), 'Hemi'] = 'Right'
df.tail()
#df.dtypes
# Out:
#                      date  gender_id     age_id  \
# 12260 2017-12-21 21:00:30          1  298414239
# 12261 2017-12-21 22:16:49          1  298414239
# 12262 2017-12-21 22:22:33          1  298414239
# 12263 2017-12-22 19:50:35          2        111
# 12264 2017-12-22 20:20:19          2        111
#
#                                     cell_name  Year   Hemi
# 12260   Slc32a1-IRES-Cre;Ai14-364558.05.01.02  2017  Right
# 12261  Chat-IRES-Cre-neo;Ai14-364380.02.02.01  2017   Left
# 12262  Chat-IRES-Cre-neo;Ai14-364380.05.02.01  2017   Left
# 12263  Chat-IRES-Cre-neo;Ai14-364381.04.02.01  2017   Left
# 12264  Chat-IRES-Cre-neo;Ai14-364381.04.02.02  2017  Right

# %% [markdown]
# ### Look for cells that do not have a qc reviewer and failed qc for project T301. What are the cell level qc failures? (access, gohm seal, blowout, input resistance)

# %%
lims_query = "SELECT err.workflow_state, err.stage1_reviewer_id, err.stage2_reviewer_id, \
err.blowout_mv, err.failed_bad_rs, err.failed_no_seal, err. failed_electrode_0, err.failed_clogged_pipette, \
err.failed_other, projects.code \
FROM ephys_roi_results err JOIN specimens ON specimens.ephys_roi_result_id = err.id \
JOIN projects ON specimens.project_id = projects.id \
WHERE (stage1_reviewer_id IS NULL \
AND err.stage2_reviewer_id IS NULL) \
AND (err.workflow_state = 'manual_failed' OR err.workflow_state = 'auto_failed') \
AND projects.code = 'T301'"



lims_df = get_lims_dataframe(lims_query)
lims_df.head()
# Out:
#    code failed_bad_rs workflow_state stage2_reviewer_id  blowout_mv  \
# 0  T301         False    auto_failed               None         NaN
# 1  T301         False    auto_failed               None         NaN
# 2  T301         False    auto_failed               None         NaN
# 3  T301         False    auto_failed               None         NaN
# 4  T301         False    auto_failed               None         NaN
#
#   stage1_reviewer_id failed_other failed_electrode_0 failed_clogged_pipette  \
# 0               None         None               True                  False
# 1               None         None              False                  False
# 2               None         None               True                  False
# 3               None         None               True                  False
# 4               None         None              False                  False
#
#   failed_no_seal
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None

# %% [markdown]
# ### Find all the H301 cells where DiJon was stage 1 reviewer that manually passed qc and the cells where Lisa was stage 2 review that manually failed qc.

# %%
lims_query = "SELECT err.workflow_state, err.stage1_reviewer_id, err.stage2_reviewer_id, projects.code \
FROM ephys_roi_results err JOIN specimens ON specimens.ephys_roi_result_id = err.id \
JOIN projects ON specimens.project_id = projects.id \
WHERE projects.code = 'H301' \
AND (err.stage1_reviewer_id = '305127608' AND err.workflow_state = 'manual_passed') \
AND (err.stage2_reviewer_id = '485591509' AND err.workflow_state = 'manual_failed')"

lims_df = get_lims_dataframe(lims_query)
lims_df
# Out:
# Could not find results for your query.
# Empty DataFrame
# Columns: []
# Index: []
